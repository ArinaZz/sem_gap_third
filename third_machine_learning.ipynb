# %% [markdown]
# # Третья лабораторная. Методы машинного обучения
#
# Лабораторная состоит из гайда по методам глубинного обучения (Deep Learning) и "продвинутым" методам машинного обучения (Machine Learning) на Python и пяти заданий:
#
# * [Задание 1](#Задание-1.) - поиск гиперпараметров случайного леса
#
# * [Задание 2](#Задание-2.) - поиск гиперпараметров нейросети для классификации
#
# * [Задание 3](#Задание-3.) - поиск гиперпараметров для градиентного бустинга
#
# * [Задание 4 (дополнительное)](#Задание-4-(дополнительное).) - выбор подходящих аугментаций. Это задание повышенной сложности, за него даётся 2.5 балла
#
# * [Задание 5 (дополнительное)](#Задание-5-(дополнительное).) - выбор модели машинного обучения для решения задачи регрессии. За это задание можно получить 1 балл
#
# Из пяти заданий требуется выполнить минимум первые 3 задания, за остальные задания можно заработать дополнительные баллы.
#
# За попадание в топ 3 по качеству модели в заданиях 3, 4 и 5 можно получить по 1 дополнительному баллу за задание.
#
# Задания 2, 3 и 4 последовательно связаны друг с другом - для одной задачи требуется добиться необходимого качества разными способами. Чтобы выполнить задание 3, требуется сначала выполнить задание 2, так как там обучается нейросеть для предобработки (имейте это в виду, если будете перезапускать ноутбук).
#
# **Не забудьте** перед отправкой на проверку добавить в репозиторий сохранённые модели (файлы из папки `models`).

# %% [markdown]
# *В этом ноутбуке изначально опущены результаты исполнения кода. Рекомендуется запускать (Shift+Enter) ячейки по мере просмотра документа*

# %% [markdown]
# #### Используемые модули
#
# Обновим пакетный менеджер pip, чтобы корректно уставить необходимые модули:

# %%
# При необходимости добавляйте опцию --user
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\arina\anaconda3\lib\site-packages (22.3)

# %% [markdown]
# Установим необходимые модули:

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: catboost==1.0.6 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.0.6)
# Requirement already satisfied: googledrivedownloader==0.4 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: joblib==1.1.0 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: keras==2.10.0 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (2.10.0)
# Requirement already satisfied: keras_tuner==1.1.3 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: matplotlib==3.5.1 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.5.1)
# Requirement already satisfied: numpy==1.21.5 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.21.5)
# Requirement already satisfied: pandas==1.4.2 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: scikit_learn==1.1.2 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\arina\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: six in c:\users\arina\anaconda3\lib\site-packages (from catboost==1.0.6->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: scipy in c:\users\arina\anaconda3\lib\site-packages (from catboost==1.0.6->-r requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: graphviz in c:\users\arina\anaconda3\lib\site-packages (from catboost==1.0.6->-r requirements.txt (line 1)) (0.20.1)
# Requirement already satisfied: plotly in c:\users\arina\anaconda3\lib\site-packages (from catboost==1.0.6->-r requirements.txt (line 1)) (5.6.0)
# Requirement already satisfied: ipython in c:\users\arina\anaconda3\lib\site-packages (from keras_tuner==1.1.3->-r requirements.txt (line 5)) (8.4.0)
# Requirement already satisfied: kt-legacy in c:\users\arina\anaconda3\lib\site-packages (from keras_tuner==1.1.3->-r requirements.txt (line 5)) (1.0.4)
# Requirement already satisfied: packaging in c:\users\arina\anaconda3\lib\site-packages (from keras_tuner==1.1.3->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: tensorboard in c:\users\arina\anaconda3\lib\site-packages (from keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.10.1)
# Requirement already satisfied: requests in c:\users\arina\anaconda3\lib\site-packages (from keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.27.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\arina\anaconda3\lib\site-packages (from matplotlib==3.5.1->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arina\anaconda3\lib\site-packages (from pandas==1.4.2->-r requirements.txt (line 8)) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arina\anaconda3\lib\site-packages (from scikit_learn==1.1.2->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (61.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (1.42.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (0.27.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (14.0.6)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (22.10.26)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorflow==2.10.0->-r requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\arina\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0->-r requirements.txt (line 10)) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\arina\anaconda3\lib\site-packages (from tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (3.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arina\anaconda3\lib\site-packages (from requests->keras_tuner==1.1.3->-r requirements.txt (line 5)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\arina\anaconda3\lib\site-packages (from requests->keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arina\anaconda3\lib\site-packages (from requests->keras_tuner==1.1.3->-r requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arina\anaconda3\lib\site-packages (from requests->keras_tuner==1.1.3->-r requirements.txt (line 5)) (3.3)
# Requirement already satisfied: backcall in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: colorama in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: decorator in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\arina\anaconda3\lib\site-packages (from ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\arina\anaconda3\lib\site-packages (from plotly->catboost==1.0.6->-r requirements.txt (line 1)) (8.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\arina\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\arina\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\arina\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\arina\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\arina\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\arina\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\arina\anaconda3\lib\site-packages (from stack-data->ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: executing in c:\users\arina\anaconda3\lib\site-packages (from stack-data->ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\arina\anaconda3\lib\site-packages (from stack-data->ipython->keras_tuner==1.1.3->-r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\arina\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\arina\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner==1.1.3->-r requirements.txt (line 5)) (3.2.2)

# %% [markdown]
# Подключим модули, которые пригодятся в мини-лабораторной.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from google_drive_downloader import GoogleDriveDownloader as gdd
import os
from pathlib import Path

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.datasets import load_wine, fetch_openml
from sklearn.manifold import TSNE, SpectralEmbedding
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import joblib

from catboost import CatBoostRegressor, CatBoostClassifier

import tensorflow as tf
from tensorflow.random import set_seed as set_random_seed
from keras import Model, Input
from keras.models import Sequential, load_model
from keras.datasets import fashion_mnist
from keras.utils.np_utils import to_categorical
from keras.layers import (Conv2D, MaxPooling2D, Flatten, Reshape, GlobalMaxPooling2D,
                          Activation, Dense, BatchNormalization)
from keras.preprocessing.image import ImageDataGenerator
import keras_tuner as kt

from save_answer import add_to_answer

# %% [markdown]
# ---
#
# ## Введение
#
# Центральное понятие в машинном обучении - **модель**. Задачей машинного обучения является создание (обучение) модели, максимально <u>качественно</u> описывающей обучающие <u>данные</u>. Цель - получить модель, способную делать полезные предсказания по новым данным.
#
# При этом критерии <u>качества</u> могут быть различными, и сильно влияют на результирующую модель. Определить *идеальный критерий*, подходящий для любого случая сложно (или невозможно). Это обусловлено как минимум двумя проблемами:
# * Данные частично некорректны - содержат шум и выбросы.
#     Шум возникает, например, из-за неточности измерений, а выбросы - чаще из-за ошибок;
# * Данные могут быть неполны - не полностью отражать действительность.
#
# Для получения полезной с практической точки зрения модели, надо учитывать, что обучающие данные (training set) могут отличаться от данных, на которых требуется вычислять предсказания (evaluation / test set).
#
#
# Как правило задачи машинного обучения разделяют на две категории:
#
# **1. [Обучение без учителя](https://scikit-learn.org/stable/unsupervised_learning.html)**
#
# * [Кластеризация](https://scikit-learn.org/stable/modules/clustering.html);
# * [Поиск ассоциативных правил](https://ru.wikipedia.org/wiki/Обучение_ассоциативным_правилам);
# * [Понижение размерности](https://scikit-learn.org/stable/modules/unsupervised_reduction.html);
# * [Поиск выбросов](https://scikit-learn.org/stable/modules/outlier_detection.html).
#
# **2. [Обучение с учителем](https://scikit-learn.org/stable/supervised_learning.html)**
#
# * [Классификация](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html);
# * Регрессия;
# * Ранжирование;
# * [Анализ выживаемости / рисков](https://nbviewer.jupyter.org/github/sebp/scikit-survival/blob/master/examples/00-introduction.ipynb).
#
# Но также есть множество задач, не вписывающихся в эти категории, например:
#
# * Multiple-instance Learning - целевые значения сопоставлены группам (bag) наблюдений;
# * One-shot Learning - классификация с одним обучающим примером для каждого класса;
# * Similarity Learning - поиск меры схожести объектов;
# * Reinforcement Learning - обучение модели, совершающей действия в ходе взаимодействия со средой;
# * Collaborative Filtering - построение рекомендаций;
# * Natural Language Processing: машинный перевод, QA - получение текстового ответа на текстовый вопрос;
# * Перенос стиля, генерирование изображений.
#
# Поэтому перед созданием модели лучше не сразу пытаться свести задачу к базовым задачам машинного обучения (классификации, регрессии), а поискать модели, использующие специфику области. Например, для машинного перевода специфичен порядок слов в предложении, и правильных переводов может быть несколько - решение задачи без использования этих особенностей приводит к крайне плохим результатам.

# %% [markdown]
# ### Overfitting / Underfitting
#
# Чтобы полученная модель была практически применима, надо соблюсти баланс между переобучением (overfitting) и недообучением (underfitting):
# * переобучение возникает, когда модель имеет минимальную ошибку на обучающем множестве, и значительно большую на тестовом;
# * недообучение возникает при использовании слишком простых моделей, которые не могут обеспечить достаточно маленькую среднюю ошибку даже на тренировочных данных.
#
# В качестве примера рассмотрим задачу одномерной регрессии с синтетическими данными:
#
# Обучающее множество: $\{(x_i, y_i)\}_{i=1}^{n}$,
# где $x_i$ - наблюдения $x \sim U([0; 1]); \varepsilon \sim N(0, 0.1)$,
# $y = f(x) + \varepsilon$,
#
# $f(x) = \cos(5 x + \frac{\pi}{2})$
#
# Для простоты будем использовать полиномиальную модель:

# %%
np.random.seed(239)

def f(x):
    return np.cos(x * 5 + np.pi/2)

X = np.sort(np.random.rand(20))
y = f(X) + np.random.normal(0, 0.1, len(X))

fig, ax = plt.subplots(1, 3, figsize=(15, 4))
X_lin = np.linspace(0, 1, 50)  # массив 50 чисел от 0 до 1
titles = ["Underfit. Degree = 2", "Best fit. Degree = 4", "Overfit. Degree = 12"]
for i, title in enumerate(titles):
    ax[i].set_title(title)
    ax[i].scatter(X, y)  # наблюдения
    ax[i].plot(X_lin, f(X_lin), color='g')  # целевая функция
# модель - полином, подбор коэффициентов - МНК
predictor_underfit = np.poly1d(np.polyfit(X, y, deg=2))
ax[0].plot(X_lin, predictor_underfit(X_lin))

predictor_best = np.poly1d(np.polyfit(X, y, deg=4))
ax[1].plot(X_lin, predictor_best(X_lin))
ax[1].plot(X_lin, f(X_lin), color='g')

predictor_overfit = np.poly1d(np.polyfit(X, y, deg=12))
ax[2].plot(X_lin, predictor_overfit(X_lin))
ax[2].plot(X_lin, f(X_lin), color='g')

ax[0].legend(["f(x)", "Prediction", "Observation"])

plt.show()

# %% [markdown]
# Заметим, что третий вариант аппроксимации функции (с переобучением) очевидно не может быть использован на практике. Как минимум, из-за слишком больших значений в промежутке от 0 до 0.1.
#
# Однако о первом варианте (с недообучением) такого сказать нельзя. Хотя полученная функция не совпадает с $f(x)$, она достаточно неплохо оценивает обучающее множество. На практике при малом числе наблюдений и большой размерности пространства сложные модели скорей всего будут склонны к переобучению, тогда как простые, вроде линейной регрессии, будут давать хоть насколько-то верную аппрокимацию.
#
# Посмотрим на ошибки в данном примере на обучающем множестве:

# %%
def print_err(title, model, x, y_true):
    mse = mean_squared_error(y_true, model(x))
    mae = mean_absolute_error(y_true, model(x))
    r2  = r2_score(y_true, model(x))
    print(title)
    print(f"MSE: {mse:.3f}, MAE: {mae:.3f}, R^2: {r2:.3f}\n")

for i, model in enumerate([predictor_underfit, predictor_best, predictor_overfit]):
    print_err(titles[i], model, X, y)
# Out:
# Underfit. Degree = 2
# MSE: 0.060, MAE: 0.206, R^2: 0.894
#
# Best fit. Degree = 4
# MSE: 0.007, MAE: 0.068, R^2: 0.987
#
# Overfit. Degree = 12
# MSE: 0.005, MAE: 0.045, R^2: 0.992

# %% [markdown]
# Здесь $R^2$ - это коэффициент детерминации. Его множество значений от $-\infty$ до $1$.
#
# Эти значения ошибок показывают насколько хорошо модель смогла запомнить обучающие данные.
#
# Попробуем применить модель к новым данным:

# %%
X_test = np.sort(np.random.rand(200))
y_test = f(X_test) + np.random.normal(0, 0.1, len(X_test))

for i, model in enumerate([predictor_underfit, predictor_best, predictor_overfit]):
    print_err(titles[i], model, X_test, y_test)
# Out:
# Underfit. Degree = 2
# MSE: 0.060, MAE: 0.205, R^2: 0.887
#
# Best fit. Degree = 4
# MSE: 0.010, MAE: 0.079, R^2: 0.982
#
# Overfit. Degree = 12
# MSE: 0.527, MAE: 0.335, R^2: 0.007

# %% [markdown]
# Видно, что качество предсказания первых двух моделей почти не упало, когда как третья (переобученная) даёт ошибку на два порядка больше. Таким образом можно выбрать наиболее корректную модель.
#
# Формально, разность между риском (математическим ожиданием ошибки) и эмпирическим риском (средним значением ошибки на обучающем множестве), называется **переобученностью**.
#
# В примере мы смогли **сгенерировать** новый набор данных, на котором проверяли насколько хорошо подходит модель, **приближая** значение переобученности (вместо математического ожидания ошибки мы вычисляли среднюю, но **не** на обучающем множестве). На практике сгенерировать новый набор данных может быть трудоёмко, или вообще невозможно, поэтому нужно уметь оценивать модель, имея только один (тренировочный) набор данных. Но как?

# %% [markdown]
# ### Кросс-валидация (Cross-Validation)
#
# Для того, чтобы понять насколько хорошо подходит модель, воспользуемся [перекрёстной проверкой](https://ru.wikipedia.org/wiki/Перекрёстная_проверка) на имеющихся обучающих данных: будем обучать модель $k$ раз, каждый раз выделяя $k-1$ долей обучающего множества для обучения модели (с нуля), используя оставшуюся долю для оценки качества. Это позволит оценить не только качество модели, но и чувствительность к обучающим данным, причём численно.
#
# Часто модели имеют гиперпараметры (параметры, значения которых фиксируются до начала обучения, например количество слоёв в нейронной сети). В примере выше гиперпараметр - это степень полинома. Подберём оптимальные гиперпараметры с помощью C-V. Для этого можно воспользоваться одной из следующих готовых реализаций:
# * [Grid-search C-V](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) - перебор значений гиперпараметров на некоторой сетке;
# * [Randomized search C-V](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) - перебор случайных значений гиперпараметров;
# * [Bayesian C-V](https://scikit-optimize.github.io/notebooks/bayesian-optimization.html) - перебор значений гиперпараметров, используя модифицируемое по ходу представление о форме поверхности ошибки. Реализован в библиотеке [hyperopt](https://hyperopt.github.io/hyperopt/).
#
# Наиболее популярный на данный момент метод - Bayesian C-V, но для простоты рассмотрим классический Grid-search C-V:

# %%
# полиномиальный регрессор - то же самое, что линейная регрессия с признаками (x^0, x^1, x^2, ..., x^k)
polynomial_regressor = make_pipeline(PolynomialFeatures(), LinearRegression())
# сетка параметров степени полинома - целые значения от 0 до 14:
parameters = {'polynomialfeatures__degree': range(15)}

# scoring - минимизируемая метрика: https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
search = GridSearchCV(polynomial_regressor, parameters, cv=5, scoring='neg_mean_squared_error')
search.fit(X[:, np.newaxis], y)
print(f"Best loss (-MSE): {search.best_score_}")
print(f"Best parameters: {search.best_params_}")
# Out:
# Best loss (-MSE): -0.13969269572542442
# Best parameters: {'polynomialfeatures__degree': 5}

# %% [markdown]
# Проблему переобучения также можно решать с помощью регуляризации (например, в случае линейных моделей – Lasso, Ridge). При этом возникают дополнительные параметры, которые имеет смысл также перебирать с помощью кросс-валидации.

# %% [markdown]
# ## Продвинутые методы машинного обучения
#
# ### Ансамблевые методы
#
# Основная идея ансамблевых методов заключается в построении набора различных примитивных базовых моделей и использовании их комбинации для предсказаний.
#
# Это позволяет бороться с двумя проблемами:
# 1. Переобучение - за счёт различия моделей (структуры или данных, на которых модели обучаются);
# 2. Низкое качество предсказаний - для большинства моделей за счёт т.н. "мудрости толпы".
#
# В качестве базовых моделей могут использоваться любые методы, от линейной регрессии до нейронных сетей, однако стоит учитывать, что:
# * время построения ансамбля сложных моделей будет очень велико. Простые же модели можно строить параллельно;
# * на [bias-variance trade-off](https://habr.com/ru/company/ods/blog/323890/#razlozhenie-oshibki-na-smeschenie-i-razbros-bias-variance-decomposition) влияет сложность каждой базовой модели и их количество. Наиболее сложные базовые модели не всегда позволяют получать лучшее качество.
#
# #### 1. Случайный лес
#
# Случайный лес - ансамбль решающих деревьев (построенных по CART). Финальный прогноз производится усреднением результатов работы каждого дерева.
#
# Для получения различных деревьев используются два принципа:
# * Bagging (Bootstrap aggregation) - выборка для каждого дерева формируется случайным образом (с возвратом) из тренировочной. Методы, использующие bagging всегда могут оценивать ошибку на "out of bag" элементах начальной выборки - тех, что не вошли ни в одну из подвыборок;
# * Random feature subspace - в качестве признаков каждое дерево рассматривает случайное подмножество исходных признаков.
#
# Одним из основных преимуществ случайных лесов для классификации является возможность предсказать не только класс, но и "уверенность" - аппроксимацию вероятности данного класса при условии входных данных. Также они могут применяться для подбора наиболее релевантных признаков - т.н. feature importances.
#
# Рассмотрим простую задачу регрессии House Prices:

# %%
# Загружаем датасет
# Функция загрузки fetch_openml возвращает пару pandas-датафреймов (таблиц, мы с ними знакомились в первой мини-лабораторной)
housing_x, housing_y = fetch_openml(name="house_prices", return_X_y=True, as_frame=True)

# Посмотрим на фичи (признаки) из датасета
housing_x.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1  2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2  3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3  4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4  5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...         0.0      0.0   None  None        None
# 1         Lvl    AllPub  ...         0.0      0.0   None  None        None
# 2         Lvl    AllPub  ...         0.0      0.0   None  None        None
# 3         Lvl    AllPub  ...         0.0      0.0   None  None        None
# 4         Lvl    AllPub  ...         0.0      0.0   None  None        None
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0     0.0    2.0  2008.0        WD         Normal
# 1     0.0    5.0  2007.0        WD         Normal
# 2     0.0    9.0  2008.0        WD         Normal
# 3     0.0    2.0  2006.0        WD        Abnorml
# 4     0.0   12.0  2008.0        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# Видим, что в таблице есть не только числовые, но и категориальные признаки (например, `MSZoning`, `LotShape` и т.д.).
#
# Обработка категориальных признаков - отдельная тема, на которую обычно выделяется часть лекции. Мы же в рамках примера оставим только числовые признаки.
#
# _На самом деле код ниже уберёт столбцы, тип которых нечисловой, но это ещё не означает, что мы убрали категориальные признаки - некоторые категориальные признаки могут в данных быть выражены в числах - это мы в данном случае проигнорируем, но стоит об этом помнить._

# %%
# Уберём все колонки, тип которых нечисловой
housing_x = housing_x.select_dtypes(['number'])

# Уберём все строки, где есть NaN - для этого надо убрать строки и в housing_x, и в housing_y.
# Чтобы корректно почистить датафреймы, сначала соединим их в 1 датафрейм, почистим его, а потом "расщепим" обратно
housing_merged = housing_x.join(housing_y)  # Соединяем датафреймы
housing_merged = housing_merged.dropna(how='any')  # Чистим
# Расщепляем датафрейм обратно на признаки объектов и их метки. В роли меток выступает SalePrice - цена дома
housing_y, housing_x = housing_merged["SalePrice"], housing_merged.drop(columns="SalePrice")

# %% [markdown]
# ---
#
# #### Задание 1.
#
# В коде ниже приведён пример запуска `RandomForestRegressor`.
#
# Требуется подобрать параметры (кроме `random_state` и `oob_score`) у `RandomForestRegressor`, чтобы [коэффициент детерминации $R^2$](http://www.machinelearning.ru/wiki/index.php?title=Коэффициент_детерминации) (оценка качетва) увеличился на **тестовых данных** до **0.75**.
#
# _В этом задании и последующих рекомендуется использовать автоматический подбор гиперпараметров вместо того, чтобы подбирать гиперпараметры вручную после каждого обучения модели, которая не смогла достичь требуемого качества._

# %%
def model_score(X, y, estimator=None, cv=3, scoring=None):
    scores = cross_val_score(estimator, X, y, cv=cv, scoring=scoring)
    return np.mean(scores)


X_train, X_test, y_train, y_test = train_test_split(housing_x, housing_y, test_size=0.25, random_state=12345)

# Ваши значения параметров - это параметры для RandomForestRegressor,
# указанные в словаре housing_params
housing_params = {
    "n_estimators": 10,
    "max_depth": 5,
    "min_samples_split": 2,
    "min_samples_leaf": 25,
    "criterion": 'squared_error',
}

housing_rf = RandomForestRegressor(
    # `random_state` оставьте зафиксированным, чтобы можно было повторить ваш результат
    random_state=12345,
    oob_score=True,
    # две звёздочки означают раскрытие словаря и передачу именованных параметров из словаря
    # прямо в конструктор RandomForestRegressor
    **housing_params,
)


housing_rf.fit(X_train, y_train)

cv_score = model_score(X_train, y_train, estimator=housing_rf, cv=10, scoring='r2')
train_score = housing_rf.score(X_train, y_train)
test_score = housing_rf.score(X_test, y_test)
oob_score = housing_rf.oob_score_
print("Score (R^2) on train:")
print(f"Out of bag training score estimation: {oob_score}")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
print("Требуемое качество на тестовых данных " + ("получено" if test_score > 0.75 else "НЕ получено"))
# Out:
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# Score (R^2) on train:
# Out of bag training score estimation: 0.7374806936219794
# Cross-validation on train score: 0.75535064759701
# Train score: 0.8111956228175592
# Test score: 0.7529692401337877
# Требуемое качество на тестовых данных получено
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Users\arina\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %% [markdown]
# Не забудьте сохранить ответы

# %%
rf_housing_model_path = os.path.join("models", "task_1.joblib")
# Создаём папку, куда сохраним результаты, если папки ещё нет
Path("models").mkdir(parents=True, exist_ok=True)

joblib.dump(housing_rf, rf_housing_model_path)  # Сохраняем итоговую модель

add_to_answer(
    "task_1",
    {
        # Перед сохранением убедитесь, что подобранные параметры
        # действительно содержатся в словаре housing_params!
        "params": housing_params,
        "model_path": rf_housing_model_path,
    },
)

# %% [markdown]
# ---
#
# Ещё одной интересной особенностью ансамблей деревьев является возможность подсчитать "*важность*" признаков. Сделаем это для рассматриваемого датасета:

# %%
importances = housing_rf.feature_importances_

ind = np.argsort(importances)[-10:]  # Найдём индексы топ-10 самых важных признаков

plt.figure(figsize=(15, 5))
plt.barh(housing_x.columns[ind], importances[ind])
plt.title("Feature importances")
plt.show()

# %% [markdown]
# Помимо того, что *важность* признаков сама по себе может быть полезной информацией для конечного пользователя, на основе неё можно производить автоматический отбор признаков.
#
# Однако следует быть осторожным с использованием такого механизма. Жадная природа алгоритма построения дерева решений может привести к неадекатным значениям такой *важности* признаков. Более надёжных методом (но тоже не идеальным!), подходящим для любых моделей, а не только для лесов, является, например, *permutation importance*.
#
# На практике помимо базового Random Forest также применяют модификации:
# * Extra Random Trees - деревья строятся не по алгоритму CART, вместо этого каждое правило деления (split point) выбирается случайным образом, после чего выбирается наиболее релевантный признак. Получается быстрое время построения, но не минимальная ошибка;
# * Rotation Random Forest - перед построением каждого дерева к набору предназначенных ему признаков применяется PCA (что означает поворот осей). Такой метод полезно использовать при больших размерностях пространства признаков.
#
# #### 2. [Градиентный бустинг](https://en.wikipedia.org/wiki/Gradient_boosting)
#
# Градиентный бустинг тоже является ансамблевым методом и имеет следующие особенности:
# * деревья строятся последовательно - каждая следующая модель старается улучшить ошибку предыдущей, аппроксимируя антиградиент <u>функции потерь</u>;
# * результат работы считается как взвешенная сумма результатов базовых моделей, веса которой определяются линейным поиском на этапе построения ансамбля;
# * в случае классификации, в сравнении со случайными лесами, градиентный бустинг не позволяет хранить в листьях деревьев классы напрямую. Вместо этого алгоритм находит вероятности классов, как в логистической регрессии. Попробуйте ответить почему это так?
#
# Модели, опирающиеся на градиентный бустинг часто дают наиболее высокое качество, в сравнении со случайными лесами, линейной регрессией, SVM и т.д.
# Однако используя градиентный бустинг гораздо легче прийти к переобучению.
#
# Одним из способов борьбы с переобучением является введение скорости обучения `learning rate` - константного множителя для каждой новой базовой модели.
#
# Посмотрим как градиентный бустинг справляется с задачей регрессии на том же датасете:

# %%
housing_gbm = GradientBoostingRegressor(
    loss='squared_error',
    learning_rate=0.1,
    n_estimators=100,
    subsample=.5,  # стохастический бустинг - деревья строятся по случайным подвыборкам
    criterion='friedman_mse',
    max_depth=3,
    random_state=12345,
)
housing_gbm.fit(X_train, y_train)

cv_score = model_score(X_train, y_train, estimator=housing_gbm, cv=10, scoring='r2')
train_score = housing_gbm.score(X_train, y_train)
test_score = housing_gbm.score(X_test, y_test)

print("Score (R^2) on train:")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Score (R^2) on train:
# Cross-validation on train score: 0.8856070965266938
# Train score: 0.9719089934613121
# Test score: 0.7141863612063776

# %% [markdown]
# На практике градиентный бустинг из библиотеки sklearn обычно не применяют. Вместо него используют одну из трёх(+) библиотек, в каждой из которых реализованы свои усовершенствования оригинального алгоритма:
# * [XGBoost](https://xgboost.readthedocs.io/en/latest/) - первая библиотека, реализующая градиентный бустинг на GPU (2014 год);
# * [LightGBM](https://lightgbm.readthedocs.io/en/latest/) - библиотека от Microsoft Research (2017 год), в которой реализована обработка категориальных признаков и усовершенствования производительности;
# * **[CatBoost](https://catboost.ai/)** - библиотека от Yandex (2017 год), в которой реализована продвинутая обработка категориальных признаков и методы борьбы с переобучением. Чаще всего в задачах с категориальными признаками CatBoost работает лучше других алгоритмов даже без подстройки параметров, однако чтобы ощутить преимущество следует не применять препроцессинг для категориальных признаков. По словам команды разработчиков, использованный метод построения симметричных деревьев (Oblivious Trees) даёт прирост в качестве во всех случаях. Хотя определяющий фактор для применения таких деревьев – эффективность реализации на GPU.
#
# Проверим смелое утверждение разработчиков `CatBoost`, не меняя ни одного параметра:

# %%
housing_catboost = CatBoostRegressor(
    verbose=False,
    allow_writing_files=False,  # не пишем логи, о них ниже
    task_type='CPU',  # или 'GPU'
)
housing_catboost.fit(X_train, y_train, eval_set=(X_test, y_test))

cv_score = model_score(X_train, y_train, estimator=housing_catboost, cv=10, scoring='r2')
train_score = r2_score(y_train, housing_catboost.predict(X_train))
test_score = r2_score(y_test, housing_catboost.predict(X_test))

print("Score (R^2) on train:")
print(f"Cross-validation on train score: {cv_score}")
print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# Score (R^2) on train:
# Cross-validation on train score: 0.897932185925525
# Train score: 0.9230097644728974
# Test score: 0.8046633561162339

# %% [markdown]
# #### Визуализация
#
# При обучении моделей градиентного бустинга или сетей очень полезно строить графики функции потерь для тренировочной и тестовой выборок.
#
# *CatBoost* сохраняет логи обучения по умолчанию (если `allow_writing_files == True`) в формат, совместимый с *TensorBoard* и *CatBoost Viewer*. Использовать *TensorBoard* для просмотра логов крайне удобно: достаточно установить *TensorBoard* (`pip install tensorboard`) и запустить его командой `tensorboard --logdir=catboost_info`. Сохранять результаты запусков алгоритма с различными параметрами можно с помощью записи логов в подкаталоги с уникальными именами. С установкой *CatBoostViewer* могут возникнуть небольшие сложности, поскольку он реализован с использованием *NodeJS*.

# %% [markdown]
# ### Нейронные сети
#
# Если вы планируете использовать нейронные сети, имеет смысл ознакомиться с [этим](https://github.com/abidlabs/AtomsOfDeepLearning/blob/master/Atomic%20Experiments%20in%20Deep%20Learning.ipynb) ноутбуком (но для выполнения лабораторной это не обязательно).
#
# С нейронными сетями чаще всего гораздо сложнее работать, чем с градиентным бустингом: приходится подбирать архитектуру, настраивать огромное число гиперпараметров; нет возможности узнать, по какому принципу сеть находит ответ. Однако есть ситуации, в которых нейронные сети просто не имеют адекватно работающих альтернатив:
# * обработка изображений, видео - Convolutional NN;
# * построение эмбеддинга с учителем и без учителя - AutoEncoder, Siamese NN;
# * работа с последовательностями, в том числе генерирование - Recurrent NN и **Transformer**;
# * создание генеративных моделей без учителя - Generative Adversarial Networks, Noise Conditional Score Network, и т.д.
#
# Большая часть преимуществ достигается из-за возможности точно управлять целью обучения с помощью функции потерь, а также возможности использовать части обученной сети для решения новой задачи. Например, научив сеть предсказывать корректность словосочетания, можно применять найденный сетью способ кодирования слов для нахождения семантической близости.
#
# #### Кратко о фреймворках
#
# Есть несколько актуальных на данный момент фреймворков для работы с нейронными сетями:
# * TensorFlow - построение статических графов вычислений, автоматический вывод градиентов, блоки для построения сетей. Имеет высокий "порог вхождения". С версии `2.0` поддерживает т.н. eager-вычисления, т.е. динамические графы. Обратная совместимость с версиями `1.*` частично отсутствует и может потреобвать переписывания части кода;
# * PyTorch - построение динамических графов вычислений, лёгкий перенос вычислений на GPU (требует изменения кода);
# * Keras - построение нейронных сетей из блоков. Вычисления производятся с помощью одного из низкоуровневых фреймворков (backend): TensorFlow, CNTK, Theano и др.
#
# Если не требуется реализовывать принципиально новый алгоритм машинного обучения, внедрять наиболее современные механизмы и т.д., проще всего использовать Keras.
#
# Для некоторых архитектур нейронных сетей пишут профильные оптимизированные решения (например, для [YOLO](https://pjreddie.com/darknet/yolo/) - алгоритма быстрого поиска объектов на изображениях реализована низкоуровневая поддержка в библиотеке [Darknet](https://github.com/pjreddie/darknet)). Фреймворки вроде TensorFlow, хоть и обеспечивающие работу с несколькими GPU в кластерах, часто проигрывают по производительности узкопрофильным решениям. На практике, если применяют TensorFlow, как правило используют [оптимизаторы](https://developer.nvidia.com/tensorrt) для ускорения инференса, а для этапа тренировки тратят приличное число ресурсов.
#
#
# #### Пример
#
# Воспользуемся фреймворком `Keras`, который работает на `Tensorflow`.

# %% [markdown]
# Построим сеть для решения задачи регрессии, рассмотренной выше.
#
# В Keras удобно строить сеть как последовательность слоёв, для этого используется *Sequential*-модель:

# %%
def make_dense_model():
    model = Sequential()
    model.add(Dense(100, input_dim=X_train.shape[1]))
    model.add(Activation('relu'))
    model.add(Dense(200))
    model.add(Activation('relu'))
    model.add(Dense(60))
    model.add(Activation('relu'))
    model.add(Dense(1))
    # чтобы модель можно было тренировать и использовать, необходимо её скомпилировать
    model.compile(optimizer='adam', loss='mae')
    
    return model


dense_model = make_dense_model()

# %% [markdown]
# Попробуем натренировать модель:

# %%
np.random.seed(1)
set_random_seed(1)

n_epochs = 800

history = dense_model.fit(
    X_train, y_train,
    epochs=n_epochs,
    # число примеров, на которых считается градиент:
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=False,  # Отключаем вывод, чтобы не перегружать ноутбук лишним выводом
)

plt.plot(range(n_epochs), (history.history['loss']), c='b')
plt.plot(range(n_epochs), (history.history['val_loss']), c='g')
plt.legend(['Train Loss', 'Validation loss'])
plt.show()

# %% [markdown]
# Рассмотрим параметры обучения:
# * `epochs` - число эпох. Эпоха заканчивается, когда сеть увидела все примеры тренировочного множества;
# * `batch_size` - размер мини-батча. В [SGD](http://www.machinelearning.ru/wiki/index.php?title=Стохастический_градиентный_спуск) элементы обучающей выборки разбиваются на группы (мини-батчи) и функция потерь, вместе с её производной, рассчитывается на мини-батчах. Веса обновляются после просмотра каждого мини-батча. Вычислительно выгодней, чтобы мини-батч был достаточно большого размера, поскольку в таком случае данные будут обрабатываться параллельно;
# * `validation_data` - данные для построения кривой ошибки на валидационных данных "Validation loss".
#
# По графику функции потерь (loss) можно судить о том, имеет ли смысл обучать сеть большее число итераций.
#
# Посмотрим на качество полученной сети:

# %%
train_score = r2_score(y_train, dense_model.predict(X_train))
test_score  = r2_score(y_test, dense_model.predict(X_test))

print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# 27/27 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# Train score: 0.9517070170085493
# Test score: 0.6553632635677454

# %% [markdown]
# Получить те же результаты можно за меньшее число эпох обучения с помощью стандартизации входных данных.
# Так происходит из-за того, что в противном случае сети приходится самой сначала "искать положение данных".
#
# Сделаем предобработку с помощью `StandardScaler` для векторов признаков и `MinMaxScaler` для целевого.
# А после каждого полносвязного (`Dense`) слоя поставим `BatchNormalization` - этот механизм стандартизации внутри сети рекомендуется применять почти во всех случаях. Грубо говоря, без него каждый слой сам должен "искать положение" своих входных данных, хотя эту операцию можно сделать явно.

# %%
X_train, X_test = X_train.to_numpy(), X_test.to_numpy()
y_train, y_test = y_train.to_numpy(), y_test.to_numpy()

# %%
np.random.seed(1)
set_random_seed(1)

scaler = StandardScaler()
target_scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
y_train_scaled = target_scaler.fit_transform(y_train.reshape(y_train.shape[0], 1))
X_test_scaled = scaler.transform(X_test)
y_test_scaled = target_scaler.transform(y_test.reshape(y_test.shape[0], 1))


def make_dense_scaled_model():
    model = Sequential()
    model.add(Dense(100, input_dim=X_train.shape[1]))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(200))
    # Добавились слои BatchNormalization
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dense(60))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mae')
    return model
    
    
dense_scaled_model = make_dense_scaled_model()

history = dense_scaled_model.fit(X_train_scaled, y_train_scaled,
                                 epochs=n_epochs,
                                 batch_size=32,
                                 validation_data=(X_test_scaled, y_test_scaled),
                                 verbose=False)

plt.plot(range(len(history.history['loss'])), history.history['loss'], c='b')
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], c='g')
plt.legend(['Train Loss', 'Validation loss'])
plt.show()

# %%
def scaled_predict(model, X, target_scaler=target_scaler):
    return target_scaler.inverse_transform(model.predict(X))


train_score = r2_score(y_train, scaled_predict(dense_scaled_model, X_train_scaled))
test_score  = r2_score(y_test, scaled_predict(dense_scaled_model, X_test_scaled))

print(f"Train score: {train_score}")
print(f"Test score: {test_score}")
# Out:
# 27/27 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train score: 0.9943516479283442
# Test score: 0.7552720656905815

# %% [markdown]
# Почистим ресурсы - освободим память от обученных моделей, чтобы приступить к следующей части лабораторной работы

# %%
del dense_model
del dense_scaled_model

# %% [markdown]
# ---

# %% [markdown]
# ### Нейронные сети для обработки изображений

# %% [markdown]
# Загрузим датасет fashion mnist, содержащий изображения одежды (grayscale 28x28) 10 различных классов:

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
classes = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Переводим цвета из диапазона [0, 255] к диапазону [0, 1]
train_images = train_images / 255.0
test_images  = test_images / 255.0
# Переводим числовые метки в категориальные - вместо номера класса от 0 до 9 будем использовать векторы
# из 10 элементов, где все нули, кроме единицы на i-ой позиции для i-го класса.
# Такой подход позволяет избежать негативных эффектов при обучении, т.к. между классами нет строгого линейного порядка,
# как в случае с числами от 0 до 9.
train_vectors = to_categorical(train_labels)
test_vectors = to_categorical(test_labels)

# %% [markdown]
# Будем пользоваться библиотекой `keras-tuner` для автоматического подбора гиперпараметров. Для того, чтобы с помощью этой библиотеки подобрать гиперпараметры, надо определить функцию, принимающую на вход специальный объект `hp` и возвращающую построенную модель.
#
# У объекта `hp` можно вызывать методы `Choice`, `Int`, `Boolean` и другие для указания, из каких значений перебирать гиперпараметры в данном месте.
#
# Ниже приведён пример кода, где определяется функция `build_model`, которая будет передана "тюнеру" для поиска лучших гиперпараметров.

# %%
np.random.seed(1)
set_random_seed(1)

def build_model(hp):
    image_model = Sequential()
    image_model.add(Reshape((28, 28, 1), input_shape=(28, 28)))
    image_model.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1), activation='relu'))
    image_model.add(BatchNormalization())
    image_model.add(MaxPooling2D())
    
    # В следующем слое сообщаем keras tuner гиперпараметры, из которых надо искать лучшие
    image_model.add(Conv2D(hp.Int(  # С помощью hp.Int перебираем целые числа в качестве гиперпараметров
                                'second_conv2d_out_channels',  # название нашего гиперпараметра, для которого ищем значение
                                min_value=4,
                                max_value=5,
                                step=1,
                            ),
                           kernel_size=(3, 3), strides=(1, 1),
                           activation=hp.Choice(  # Перебираем значения в качестве гиперпараметров
                               'second_conv2d_activation',  # название нашего гиперпараметра, для которого ищем значение
                               ['relu', 'tanh'],  # список, из которого можно выбирать значения гиперпараметра
                           )))
    
    # Следующий гиперпараметр - "наличие слоя батч-нормализации"
    if hp.Boolean("need_batch_norm_after_second_conv2d"):
        # Сюда зайдём в случае, когда keras-tuner подставит True в качестве гиперпараметра need_batch_norm_after_second_conv2d
        # И тогда в модель будет добавлен слой батч-нормализации
        image_model.add(BatchNormalization())
    
    image_model.add(MaxPooling2D())
    image_model.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1), activation='relu'))
    image_model.add(BatchNormalization())
    image_model.add(Flatten())

    image_model.add(Dense(4, activation='relu'))
    image_model.add(Dense(10, activation='softmax'))
    image_model.compile(optimizer='adam',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])
    # Функция должна возвращать построенную и скомпилированную модель
    return image_model

# %% [markdown]
# Далее создадим тюнер, который будет искать лучшие гиперпараметры из заданных с помощью случайного поиска (random search).
#
# Случайный поиск используется, когда возможных конфигураций модели слишком много, так как процесс обучения одной модели может быть затратным. При случайном поиске гиперпараметры будут выбираться из возможных случайным образом. Нам нужно лишь указать максимальное количество различных моделей, которые следует обучать.
#
# Лучшими гиперпараметрами тюнер считает модель, которая после обучения показала лучшее качество по метрике, переданной аргументом `objective`.

# %%
# Создаём тюнер
tuner = kt.RandomSearch(
    build_model,  # Передаём функцию, определённую выше
    objective='val_loss',  # Передаём критерий качества лучшей модели
    max_trials=3,  # Максимальное кол-во возможных конфигураций, которые тюнер "проверит"
    seed=1234,
)

# Запускаем процесс поиска
# В качестве аргументов передаём всё то, что передали бы в метод fit, если бы подбора гиперпараметров не было
tuner.search(train_images, train_vectors, epochs=5, batch_size=128, validation_data=(test_images, test_vectors))
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\untitled_project\oracle.json
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %% [markdown]
# Посмотрим итоги поиска

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in .\untitled_project
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001DAE9251D90>
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 5
# second_conv2d_activation: tanh
# need_batch_norm_after_second_conv2d: True
# Score: 0.5937583446502686
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 5
# second_conv2d_activation: tanh
# need_batch_norm_after_second_conv2d: False
# Score: 0.5972707271575928
# Trial summary
# Hyperparameters:
# second_conv2d_out_channels: 4
# second_conv2d_activation: relu
# need_batch_norm_after_second_conv2d: True
# Score: 0.61515212059021

# %% [markdown]
# Создадим модель, которую тюнер признал лучшей

# %%
best_model = tuner.get_best_models()[0]  # Создадим модель
best_model.build(input_shape=(None, 28, 28))  # Построим модель с лучшими гиперпараметрами
best_model.summary()  # Посмотрим на архитектуру построенной модели, она соответствует выбранным гиперпараметрам
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 26, 26, 4)         40
#
#  batch_normalization (BatchN  (None, 26, 26, 4)        16
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 4)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 5)         185
#
#  batch_normalization_1 (Batc  (None, 11, 11, 5)        20
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 5)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 4)           184
#
#  batch_normalization_2 (Batc  (None, 3, 3, 4)          16
#  hNormalization)
#
#  flatten (Flatten)           (None, 36)                0
#
#  dense (Dense)               (None, 4)                 148
#
#  dense_1 (Dense)             (None, 10)                50
#
# =================================================================
# Total params: 659
# Trainable params: 633
# Non-trainable params: 26
# _________________________________________________________________

# %% [markdown]
# Замерим `accuracy` для найденной модели на тестовых данных

# %%
# Так как мы кодировали метки векторами, можем раскодировать их обратно,
# воспользовавшись функцией argmax - находит индекс максимального элемента вектора
print(f"Качество найденной модели: {accuracy_score(test_labels, np.argmax(best_model.predict(test_images), axis=-1))}")
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Качество найденной модели: 0.7797

# %% [markdown]
# #### Задание 2.
#
# Измените параметры свёрточной сети / параметры обучения (метода `fit`), чтобы повысить качество (accuracy) на **тестовых данных** до **0.88**.
#
# При желании можно использовать автоматический подбор гиперпараметров с помощью keras-tuner, но можно обойтись и без него.
#
# Если Вы перезапустили ноутбук, надо заново загрузить датасет, выполнив начальную ячейку с кодом в разделе [Нейронные сети для обработки изображений](#Нейронные-сети-для-обработки-изображений).

# %%
np.random.seed(1)
set_random_seed(1)

classification_model = Sequential()
classification_model.add(Reshape((28, 28, 1), input_shape=(28, 28)))
# далее input_shape указывать не обязательно
# следует изменить параметры следующих слоёв:
classification_model.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1),
                       input_shape=(28, 28, 1), activation='relu'))
classification_model.add(BatchNormalization())
classification_model.add(MaxPooling2D())
classification_model.add(Conv2D(64, kernel_size=(3, 3), strides=(1, 1),
                       input_shape=(14, 14, 4), activation='relu'))
classification_model.add(BatchNormalization())
classification_model.add(MaxPooling2D())
classification_model.add(Conv2D(128, kernel_size=(3, 3), strides=(1, 1),
                       input_shape=(7, 7, 4), activation='relu'))
classification_model.add(BatchNormalization())

# Слой ниже (и последующие слои) менять не надо
classification_model.add(Flatten(name='flatten'))
classification_model.add(Dense(4, activation='relu'))
classification_model.add(Dense(10, activation='softmax'))

# %%
classification_model.compile(optimizer='adam', 
                             loss='categorical_crossentropy',
                             metrics=['accuracy'])

classification_model.fit(train_images, train_vectors, epochs=5, batch_size=32,
                         validation_data=(test_images, test_vectors))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.7462 - accuracy: 0.7579 - val_loss: 0.4181 - val_accuracy: 0.8520
# Epoch 2/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3455 - accuracy: 0.8743 - val_loss: 0.3778 - val_accuracy: 0.8655
# Epoch 3/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2953 - accuracy: 0.8926 - val_loss: 0.3260 - val_accuracy: 0.8848
# Epoch 4/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2663 - accuracy: 0.9013 - val_loss: 0.3405 - val_accuracy: 0.8846
# Epoch 5/5
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.2418 - accuracy: 0.9106 - val_loss: 0.3059 - val_accuracy: 0.8978

# %%
def evaluate_model_for_task_2(model):
    test_acc = accuracy_score(test_labels, np.argmax(model.predict(test_images), axis=-1))
    print(f"Качество: {test_acc}")
    print("Тест на качество {}".format("НЕ пройден :(" if 0.88 > test_acc else "пройден :)"))

# %% [markdown]
# Вызовите функцию `evaluate_model_for_task_2`, передав ей обученную модель, чтобы увидеть качество этой модели. При сдаче задания качество должно быть не ниже **0.88**.
#
# Не забудьте сохранить модель, выполнив ячейки ниже.
#
# _Примечание: модель, полученная в ходе выполнения этого задания, будет использована далее, поэтому важно, чтобы она называлась_ `classification_model`

# %%
#  classification_model = best_model
evaluate_model_for_task_2(classification_model)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Качество: 0.8978
# Тест на качество пройден :)

# %% [markdown]
# Модель понадобится в следующем задании, поэтому сохраним её

# %%
second_task_saved_model = os.path.join("models", "task_2_weights.h5")
# Создаём папку, куда сохраним результаты, если папки ещё нет
Path("models").mkdir(parents=True, exist_ok=True)
classification_model.save(second_task_saved_model)

add_to_answer(
    "task_2",
    {
        "model_path": second_task_saved_model,
    },
)

# %% [markdown]
# ---
#
# Посмотрим как выглядит предсказание:

# %%
np.random.seed(123456)
test_ind = np.random.randint(test_images.shape[0])
test_image = test_images[test_ind]
test_vector = test_vectors[test_ind]
predicted_test_vector = classification_model.predict(test_image[np.newaxis]).reshape((10,))

plt.imshow(test_image, cmap='gray')
plt.title('Тестовое изображение')
plt.figure()

fig, ax = plt.subplots(1, 2, figsize=(17, 4))
ax[0].bar(range(10), test_vector, tick_label=classes)
ax[1].bar(range(10), predicted_test_vector, tick_label=classes)
for i, title in enumerate(['Правильный вектор классов', 'Предсказанный вектор']): ax[i].set_title(title)
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# Получим предсказания для первых 100 изображений:

# %%
# %time
predicted_vectors = classification_model.predict(test_images[:100]).reshape((100, 10))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# Посмотрим на каких изображениях сеть ошибается:

# %%
predicted_labels = np.argmax(predicted_vectors, axis=1)  # предсказанные индексы классов - где верояность наибольшая

pred = test_labels[:100] != predicted_labels
misclassified_images = test_images[:100][pred]
misclassified_correct = test_labels[:100][pred]
misclassified_predicted = predicted_labels[:100][pred]

cm = confusion_matrix(test_labels[:100], predicted_labels[:100])
plt.imshow(cm, interpolation='nearest')
plt.xticks(range(10), classes, rotation=90)
plt.yticks(range(10), classes)
plt.colorbar()
plt.title("Confusion matrix")
plt.figure()

fig, ax = plt.subplots(2, 6, figsize=(15, 4))
for i in range(2 * 6):
    ax.flatten()[i].imshow(misclassified_images[i], cmap='gray')
    ax.flatten()[i].axis('off')
    ax.flatten()[i].set_title(f"{classes[misclassified_predicted[i]]} / {classes[misclassified_correct[i]]}")

# %% [markdown]
# ---
#
# ### Gradient Boosting для классификации изображений
#
#
#
# Будем рассматривать ту же задачу, что и в прошлом задании.

# %% [markdown]
# _Примечание:_ здесь используем модель-результат второго задания - `classification_model` (модель-классификатор). Если ноутбук перезагружался, можно выполнить ячейку с кодом ниже, чтобы загрузить датасет и обученную в задании модель в память.
#
# _Ещё примечание:_ второе задание, выполненное до этого шага, могло потребовать много ресурсов компьютера (особенно, если был использован keras tuner). Так как модель, полученная в прошлом задании, была сохранена, может быть удобно перезагрузить ноутбук, чтобы освободить занятые ресурсы, для выполнения следующих заданий.

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
classes = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Переводим цвета из диапазона [0, 255] к диапазону [0, 1]
train_images = train_images / 255.0
test_images  = test_images / 255.0
# Переводим числовые метки в категориальные - вместо номера класса от 0 до 9 будем использовать векторы
# из 10 элементов, где все нули, кроме единицы на i-ой позиции для i-го класса.
# Такой подход позволяет избежать негативных эффектов при обучении, т.к. между классами нет строгого линейного порядка,
# как в случае с числами от 0 до 9.
train_vectors = to_categorical(train_labels)
test_vectors = to_categorical(test_labels)

second_task_saved_model = os.path.join("models", "task_2_weights.h5")
classification_model = load_model(second_task_saved_model)

# %% [markdown]
# Возьмём лишь часть модели `classification_model` (до полносвязных слоёв), чтобы получить векторы признаков - именно для этого при создании модели мы помечали слой `Flatten`.

# %%
# Из слоёв classification_model составим модель для извлечения вектора признаков
feature_extractor = Model(
    inputs=classification_model.inputs,
    outputs=classification_model.get_layer(name="flatten").output,  # Указываем слой, выходы после которого нас интересуют
)

# %% [markdown]
# Получим векторы признаков:

# %%
# Здесь predict означает прогон данных через feature_extractor: получаем промежуточные
# представления исходных объектов, чтобы на этих представлениях было проще обучить градиентный бустинг.
train_encoded = feature_extractor.predict(train_images, batch_size=32)
test_encoded = feature_extractor.predict(test_images, batch_size=32)
print(f'train_encoded.shape = {train_encoded.shape}')
print(f'test_encoded.shape = {test_encoded.shape}')
# Out:
# 1875/1875 [==============================] - 6s 3ms/step
# 313/313 [==============================] - 1s 3ms/step
# train_encoded.shape = (60000, 1152)
# test_encoded.shape = (10000, 1152)

# %% [markdown]
# ---
#
# #### Задание 3.
#
# Для векторов признаков, полученных из предыдущего задания, достроим классификатор на основе градиентного бустинга.
#
# **Требуется:**
#
# Изменить параметры `CatBoostClassifier` ниже, чтобы повысить качество (accuracy) на **тестовых данных** до **0.89**.
#
# _Примечание:_ в случае, если ресурсов компьютера не хватает, и не помогает перезагрузка jupyter-ноутбука, можно попробовать выполнить это задание в [Google Colab](https://colab.research.google.com/). В таком случае не забудьте перенести в Colab сохранённую со второго задания модель, а после выполнения не забудьте добавить все необходимые данные в репозиторий.

# %%
dim_reduction = PCA(n_components=train_encoded.shape[-1] // 4) # понизим размерность, используя информацию о классах
small_train_encoded = dim_reduction.fit_transform(train_encoded)
small_test_encoded = dim_reduction.transform(test_encoded)

# %%
image_gbm = CatBoostClassifier(
    loss_function='MultiClass',
    # эти параметры следует подобрать:
    depth=3,
    learning_rate=0.1,
    iterations=1000,
)
image_gbm.fit(small_train_encoded, train_labels, verbose=0)

# %%
image_gbm_labels = image_gbm.predict(small_test_encoded)
image_gbm_score = accuracy_score(test_labels, image_gbm_labels)
print(f"Качество: {image_gbm_score}")
print(f"Порог по качеству " + ("пройден" if image_gbm_score >= 0.89 else "НЕ пройден"))
# Out:
# Качество: 0.896
# Порог по качеству пройден

# %% [markdown]
# Не забудьте сохранить ответ

# %%
third_task_saved_model = os.path.join("models", "task_3.cbm")
# Создаём папку, куда сохраним результаты, если папки ещё нет
Path("models").mkdir(parents=True, exist_ok=True)
image_gbm.save_model(third_task_saved_model)

add_to_answer(
    "task_3",
    {
        "model_path": third_task_saved_model,
    },
)

# %% [markdown]
# ---
#
# ## Аугментация
#
# Часто доступные на этапе обучения размеченные данные оказываются смещёнными, не целиком покрывающими допустимое для данной задачи распределение входных данных.
# Также, при использовании нейронных сетей с большим числом параметров, на этапе обучения необходимо большое число различных данных, чтобы модель не деградировала до "табличной функции", запоминая все входные данные.
#
# Для борьбы с обеими проблемами хорошо подходит подход искусственного расширения обучающего набора данных – аугментация. Идея заключается в применении случайных трансформаций к каждому отдельному изображению, при сохранении меток классов. Таким образом можно получить датасет произвольного размера и добиться от нейронной сети определённых свойств (разумеется, для фиксированного, ограниченного распределения входных данных), например: инвариантности к повороту объекта – за счёт обучения на всевозможных поворотах входных изображений.
#
# Важно, что выбор набора трансформаций и распределений из которых генерируются их параметры, специфичен для каждой задачи. Например, при классификации деревьев не разумно выполнять повороты на $\pi$, поскольку известно, что деревья всегда растут снизу вверх.
#
# ---
#
# Будем загружать датасет из GoogleDisk, воспользуемся библиотекой `googledrivedownloader`.

# %% [markdown]
# Скачаем файлы с данными:

# %%
ids_to_file_names = {
    '1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv': 'fashion_images.npy',
    '15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI': 'fashion_labels.npy',
    '1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o': 'val_fashion_images.npy',
    '1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y': 'val_fashion_labels.npy',
    '1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4': 'test_fashion_images.npy',
}

# Файлы будем загружать и сохранять в папку data
for _id in ids_to_file_names:
    ids_to_file_names[_id] = os.path.join("data", ids_to_file_names[_id])
    
# Создадим папку data, если её ещё нет
Path("data").mkdir(parents=True, exist_ok=True)
    
    
for file_id in ids_to_file_names:
    # Качаем файл только если он ещё не скачан
    if not os.path.isfile(ids_to_file_names[file_id]):
        gdd.download_file_from_google_drive(file_id=file_id,
                                            dest_path=os.path.join('.', ids_to_file_names[file_id]),
                                            unzip=True)
# Out:
# Downloading 1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv into .\data\fashion_images.npy... Done.
# Unzipping...Downloading 15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI into .\data\fashion_labels.npy...
# C:\Users\arina\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1iFK4-fCqs8l5lWmYnUYlkv28GDb43FUv" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o into .\data\val_fashion_images.npy...
# C:\Users\arina\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "15NUcK_Pg4iEUttK1XiG0SonJaEbaaVnI" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y into .\data\val_fashion_labels.npy...
# C:\Users\arina\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1AXtbCz3EE2xVuUrGgEco7a-lMh8Vqm0o" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...Downloading 1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4 into .\data\test_fashion_images.npy...
# C:\Users\arina\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1fk1mZxBLRryWp4IoLHRr5IwiaKy4WL_Y" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))
# Done.
# Unzipping...
# C:\Users\arina\anaconda3\lib\site-packages\google_drive_downloader\google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1tWy1d9lkrCzkiSZBlfd1G6YV4sZ7pNt4" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))

# %% [markdown]
# Загрузим данные – изображения 64x64 с цветным шумом и случайно аффинно трансформированными снимками одежды:

# %%
def load_from_data(fname):
    return np.load(os.path.join("data", fname))

fashion_images = load_from_data("fashion_images.npy")
fashion_labels = load_from_data("fashion_labels.npy")

val_fashion_images = load_from_data("val_fashion_images.npy")
val_fashion_labels = load_from_data("val_fashion_labels.npy")

test_fashion_images = load_from_data("test_fashion_images.npy")

# %% [markdown]
# В качестве тренировочного и валидационного датасета даны изображения и метки (вектора вероятностей классов одежды), в качестве тестового – только изображения.

# %% [markdown]
# Ниже дана модель, гиперпараметры которой (количества каналов, размеры ядер, функции активации, архитектуру и т.п.) менять **нельзя**.

# %%
def make_fashion_model():
    imodel = Sequential()
    imodel.add(Reshape((64, 64, 3), input_shape=(64, 64, 3)))
    imodel.add(Conv2D(4, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(8, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(16, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(32, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(64, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(MaxPooling2D())
    imodel.add(Conv2D(128, kernel_size=(3, 3), strides=(1, 1),
                         activation='relu', padding='same'))
    imodel.add(BatchNormalization())
    imodel.add(Flatten())

    iclf = Sequential()
    iclf.add(imodel)
    iclf.add(Dense(10, activation='softmax'))

    iclf.compile(optimizer='adam', 
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    
    return iclf

# %% [markdown]
# ---
#
# #### Задание 4 (дополнительное).
#
# **Внимание!** Это задание повышенной сложности, за его решение даётся 2.5 балла, выполнять его необязательно.
#
# Найти такие параметры аугментации (ниже), чтобы качество классификации (accuracy) на **тестовых** данных было **не ниже 0.6**.
#
# *Настоятельно рекомендуется сначала внимательно изучить обучающую и тестовую выборки, а не подбирать параметры случайным образом.*

# %%
train_fashion_images = fashion_images.copy()
# здесь можно сделать предварительную обработку всего обучающего датасета
train_fashion_images = np.roll(train_fashion_images, (15, 10), (1, 2))
#train_fashion_images = np.array([rotate(img, 30, mode='reflect', clip=False) for img in train_fashion_images])
train_fashion_labels = fashion_labels

# %%
# здесь следует изменить параметры аугментации (параметры ImageDataGenerator):
aug_params = {  # Параметры задаём сначала в словаре, чтобы их потом сохранить
    "featurewise_center": False,
    "samplewise_center": False,
    "featurewise_std_normalization": False,
    "samplewise_std_normalization": False,
    "rotation_range": 45,
    "width_shift_range": 20,
    "height_shift_range": 20,
    "brightness_range": None,
    "shear_range": 0.0,
    "zoom_range": 0.0,
    "channel_shift_range": 0.05,
    "fill_mode": 'constant',
    "cval": 0.0,
    "horizontal_flip": True,
    "vertical_flip": False,
    "rescale": None,
}

aug = ImageDataGenerator(**aug_params)

# %% [markdown]
# Из параметров обучения можно менять `batch_size` и `epochs`, но использовать можно не больше 200 эпох.
#
# При желании можно разобраться в механизме callback'ов и передать в `fit` дополнительные параметры для автоматического сохранения весов модели к состоянию на "лучшей" итерации обучения (лучшей с точки зрения качества на валидационных данных), но это делать не обязательно.

# %%
fit_params = {
    "batch_size": 100,
    "epochs": 200,
}

fashion_clf = make_fashion_model()

aug.fit(train_fashion_images)
gen = aug.flow(train_fashion_images, train_fashion_labels,
               batch_size=fit_params["batch_size"])

hist = fashion_clf.fit(
    gen,
    steps_per_epoch=len(train_fashion_images) // fit_params["batch_size"],
    validation_data=(val_fashion_images, val_fashion_labels),
    **fit_params,
)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 3s 189ms/step - loss: 2.6578 - accuracy: 0.1330 - val_loss: 2.3017 - val_accuracy: 0.1200
# Epoch 2/200
# 10/10 [==============================] - 2s 160ms/step - loss: 2.3269 - accuracy: 0.1870 - val_loss: 2.3183 - val_accuracy: 0.0600
# Epoch 3/200
# 10/10 [==============================] - 2s 154ms/step - loss: 2.1135 - accuracy: 0.2330 - val_loss: 2.3326 - val_accuracy: 0.0400
# Epoch 4/200
# 10/10 [==============================] - 2s 155ms/step - loss: 1.9447 - accuracy: 0.2960 - val_loss: 2.3379 - val_accuracy: 0.0400
# Epoch 5/200
# 10/10 [==============================] - 2s 156ms/step - loss: 1.8563 - accuracy: 0.3370 - val_loss: 2.3534 - val_accuracy: 0.0400
# Epoch 6/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.7868 - accuracy: 0.3470 - val_loss: 2.3660 - val_accuracy: 0.1200
# Epoch 7/200
# 10/10 [==============================] - 2s 165ms/step - loss: 1.6666 - accuracy: 0.3980 - val_loss: 2.3650 - val_accuracy: 0.1000
# Epoch 8/200
# 10/10 [==============================] - 2s 153ms/step - loss: 1.6636 - accuracy: 0.3810 - val_loss: 2.3620 - val_accuracy: 0.1000
# Epoch 9/200
# 10/10 [==============================] - 2s 155ms/step - loss: 1.6191 - accuracy: 0.4080 - val_loss: 2.3634 - val_accuracy: 0.1000
# Epoch 10/200
# 10/10 [==============================] - 2s 154ms/step - loss: 1.5247 - accuracy: 0.4600 - val_loss: 2.3936 - val_accuracy: 0.1000
# Epoch 11/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.5248 - accuracy: 0.4280 - val_loss: 2.4205 - val_accuracy: 0.1000
# Epoch 12/200
# 10/10 [==============================] - 2s 159ms/step - loss: 1.4421 - accuracy: 0.4680 - val_loss: 2.4410 - val_accuracy: 0.1000
# Epoch 13/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.4188 - accuracy: 0.4920 - val_loss: 2.4266 - val_accuracy: 0.1000
# Epoch 14/200
# 10/10 [==============================] - 2s 150ms/step - loss: 1.4360 - accuracy: 0.4700 - val_loss: 2.4616 - val_accuracy: 0.1200
# Epoch 15/200
# 10/10 [==============================] - 2s 151ms/step - loss: 1.3642 - accuracy: 0.4930 - val_loss: 2.4804 - val_accuracy: 0.1000
# Epoch 16/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.3482 - accuracy: 0.5210 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 17/200
# 10/10 [==============================] - 2s 164ms/step - loss: 1.3340 - accuracy: 0.4970 - val_loss: 2.4273 - val_accuracy: 0.1000
# Epoch 18/200
# 10/10 [==============================] - 2s 161ms/step - loss: 1.3043 - accuracy: 0.5230 - val_loss: 2.4610 - val_accuracy: 0.1000
# Epoch 19/200
# 10/10 [==============================] - 2s 153ms/step - loss: 1.2538 - accuracy: 0.5330 - val_loss: 2.4445 - val_accuracy: 0.1200
# Epoch 20/200
# 10/10 [==============================] - 2s 155ms/step - loss: 1.2479 - accuracy: 0.5430 - val_loss: 2.4764 - val_accuracy: 0.1000
# Epoch 21/200
# 10/10 [==============================] - 2s 159ms/step - loss: 1.2720 - accuracy: 0.5210 - val_loss: 2.3970 - val_accuracy: 0.1200
# Epoch 22/200
# 10/10 [==============================] - 2s 147ms/step - loss: 1.2333 - accuracy: 0.5420 - val_loss: 2.4418 - val_accuracy: 0.1200
# Epoch 23/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.1930 - accuracy: 0.5540 - val_loss: 2.4680 - val_accuracy: 0.1400
# Epoch 24/200
# 10/10 [==============================] - 2s 149ms/step - loss: 1.2228 - accuracy: 0.5370 - val_loss: 2.5047 - val_accuracy: 0.1200
# Epoch 25/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.2209 - accuracy: 0.5490 - val_loss: 2.5789 - val_accuracy: 0.1600
# Epoch 26/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.1826 - accuracy: 0.5580 - val_loss: 2.4978 - val_accuracy: 0.2400
# Epoch 27/200
# 10/10 [==============================] - 2s 161ms/step - loss: 1.1353 - accuracy: 0.5770 - val_loss: 2.4792 - val_accuracy: 0.1800
# Epoch 28/200
# 10/10 [==============================] - 2s 154ms/step - loss: 1.1605 - accuracy: 0.5810 - val_loss: 2.6556 - val_accuracy: 0.1800
# Epoch 29/200
# 10/10 [==============================] - 2s 153ms/step - loss: 1.0925 - accuracy: 0.6040 - val_loss: 2.4807 - val_accuracy: 0.2000
# Epoch 30/200
# 10/10 [==============================] - 2s 155ms/step - loss: 1.0973 - accuracy: 0.6040 - val_loss: 2.4089 - val_accuracy: 0.2400
# Epoch 31/200
# 10/10 [==============================] - 2s 152ms/step - loss: 1.0986 - accuracy: 0.5890 - val_loss: 2.6141 - val_accuracy: 0.1800
# Epoch 32/200
# 10/10 [==============================] - 2s 153ms/step - loss: 1.0916 - accuracy: 0.5860 - val_loss: 2.3050 - val_accuracy: 0.2400
# Epoch 33/200
# 10/10 [==============================] - 2s 151ms/step - loss: 1.0690 - accuracy: 0.6060 - val_loss: 2.1463 - val_accuracy: 0.2200
# Epoch 34/200
# 10/10 [==============================] - 2s 150ms/step - loss: 1.0598 - accuracy: 0.6070 - val_loss: 2.1062 - val_accuracy: 0.1800
# Epoch 35/200
# 10/10 [==============================] - 2s 147ms/step - loss: 1.0505 - accuracy: 0.5910 - val_loss: 2.0988 - val_accuracy: 0.2400
# Epoch 36/200
# 10/10 [==============================] - 2s 150ms/step - loss: 1.0592 - accuracy: 0.6090 - val_loss: 2.1772 - val_accuracy: 0.2200
# Epoch 37/200
# 10/10 [==============================] - 2s 148ms/step - loss: 1.0461 - accuracy: 0.6020 - val_loss: 2.2978 - val_accuracy: 0.3000
# Epoch 38/200
# 10/10 [==============================] - 2s 151ms/step - loss: 1.0526 - accuracy: 0.5850 - val_loss: 2.1343 - val_accuracy: 0.3000
# Epoch 39/200
# 10/10 [==============================] - 2s 151ms/step - loss: 1.0532 - accuracy: 0.6020 - val_loss: 1.9782 - val_accuracy: 0.3200
# Epoch 40/200
# 10/10 [==============================] - 2s 149ms/step - loss: 1.0351 - accuracy: 0.6110 - val_loss: 1.7854 - val_accuracy: 0.3400
# Epoch 41/200
# 10/10 [==============================] - 2s 156ms/step - loss: 1.0231 - accuracy: 0.6100 - val_loss: 1.8649 - val_accuracy: 0.3400
# Epoch 42/200
# 10/10 [==============================] - 2s 161ms/step - loss: 1.0110 - accuracy: 0.6190 - val_loss: 1.6297 - val_accuracy: 0.3800
# Epoch 43/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.9926 - accuracy: 0.6320 - val_loss: 1.7097 - val_accuracy: 0.3400
# Epoch 44/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.9955 - accuracy: 0.6160 - val_loss: 1.5825 - val_accuracy: 0.4000
# Epoch 45/200
# 10/10 [==============================] - 2s 161ms/step - loss: 0.9808 - accuracy: 0.6200 - val_loss: 1.5634 - val_accuracy: 0.3800
# Epoch 46/200
# 10/10 [==============================] - 2s 160ms/step - loss: 0.9502 - accuracy: 0.6270 - val_loss: 1.4401 - val_accuracy: 0.4400
# Epoch 47/200
# 10/10 [==============================] - 2s 158ms/step - loss: 0.9679 - accuracy: 0.6330 - val_loss: 1.5505 - val_accuracy: 0.5000
# Epoch 48/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.9692 - accuracy: 0.6190 - val_loss: 1.4109 - val_accuracy: 0.4400
# Epoch 49/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.9874 - accuracy: 0.6360 - val_loss: 1.3206 - val_accuracy: 0.4800
# Epoch 50/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.9893 - accuracy: 0.6380 - val_loss: 1.1890 - val_accuracy: 0.5200
# Epoch 51/200
# 10/10 [==============================] - 2s 156ms/step - loss: 0.9508 - accuracy: 0.6510 - val_loss: 1.2427 - val_accuracy: 0.5000
# Epoch 52/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.9205 - accuracy: 0.6390 - val_loss: 1.3224 - val_accuracy: 0.4600
# Epoch 53/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.9806 - accuracy: 0.6430 - val_loss: 1.2243 - val_accuracy: 0.5200
# Epoch 54/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.9088 - accuracy: 0.6540 - val_loss: 1.2002 - val_accuracy: 0.4800
# Epoch 55/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.9391 - accuracy: 0.6490 - val_loss: 1.1643 - val_accuracy: 0.5200
# Epoch 56/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.9120 - accuracy: 0.6540 - val_loss: 1.1257 - val_accuracy: 0.5200
# Epoch 57/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8956 - accuracy: 0.6650 - val_loss: 1.0556 - val_accuracy: 0.5600
# Epoch 58/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.9216 - accuracy: 0.6580 - val_loss: 1.2189 - val_accuracy: 0.5000
# Epoch 59/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.8901 - accuracy: 0.6590 - val_loss: 1.0256 - val_accuracy: 0.5600
# Epoch 60/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.8957 - accuracy: 0.6630 - val_loss: 1.1329 - val_accuracy: 0.5000
# Epoch 61/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8609 - accuracy: 0.6710 - val_loss: 1.2507 - val_accuracy: 0.5200
# Epoch 62/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.9055 - accuracy: 0.6570 - val_loss: 0.9951 - val_accuracy: 0.6000
# Epoch 63/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.9207 - accuracy: 0.6630 - val_loss: 1.0571 - val_accuracy: 0.5800
# Epoch 64/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8823 - accuracy: 0.6720 - val_loss: 1.0442 - val_accuracy: 0.6200
# Epoch 65/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.8783 - accuracy: 0.6810 - val_loss: 1.0355 - val_accuracy: 0.6000
# Epoch 66/200
# 10/10 [==============================] - 2s 170ms/step - loss: 0.8998 - accuracy: 0.6680 - val_loss: 1.0856 - val_accuracy: 0.5800
# Epoch 67/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.8497 - accuracy: 0.6690 - val_loss: 0.9992 - val_accuracy: 0.6600
# Epoch 68/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.8955 - accuracy: 0.6630 - val_loss: 1.1192 - val_accuracy: 0.5200
# Epoch 69/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.8757 - accuracy: 0.6800 - val_loss: 1.3222 - val_accuracy: 0.5600
# Epoch 70/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.8680 - accuracy: 0.6890 - val_loss: 1.1712 - val_accuracy: 0.5600
# Epoch 71/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8817 - accuracy: 0.6580 - val_loss: 1.3358 - val_accuracy: 0.6000
# Epoch 72/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.8326 - accuracy: 0.6730 - val_loss: 1.0945 - val_accuracy: 0.6600
# Epoch 73/200
# 10/10 [==============================] - 2s 160ms/step - loss: 0.8396 - accuracy: 0.6780 - val_loss: 1.1896 - val_accuracy: 0.6000
# Epoch 74/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.8675 - accuracy: 0.6620 - val_loss: 1.0985 - val_accuracy: 0.6400
# Epoch 75/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.8768 - accuracy: 0.6600 - val_loss: 1.0636 - val_accuracy: 0.5200
# Epoch 76/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.8261 - accuracy: 0.6820 - val_loss: 1.0581 - val_accuracy: 0.5800
# Epoch 77/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8723 - accuracy: 0.6690 - val_loss: 1.1468 - val_accuracy: 0.6000
# Epoch 78/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.8380 - accuracy: 0.6780 - val_loss: 1.1041 - val_accuracy: 0.5600
# Epoch 79/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.8657 - accuracy: 0.6800 - val_loss: 0.9918 - val_accuracy: 0.6600
# Epoch 80/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8295 - accuracy: 0.6700 - val_loss: 0.9032 - val_accuracy: 0.6800
# Epoch 81/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.8160 - accuracy: 0.6770 - val_loss: 0.9398 - val_accuracy: 0.6800
# Epoch 82/200
# 10/10 [==============================] - 1s 145ms/step - loss: 0.8274 - accuracy: 0.6820 - val_loss: 0.9717 - val_accuracy: 0.6400
# Epoch 83/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8160 - accuracy: 0.6880 - val_loss: 1.0944 - val_accuracy: 0.6200
# Epoch 84/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.8478 - accuracy: 0.6840 - val_loss: 1.0794 - val_accuracy: 0.5800
# Epoch 85/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.8318 - accuracy: 0.6840 - val_loss: 1.0638 - val_accuracy: 0.5800
# Epoch 86/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.8424 - accuracy: 0.6660 - val_loss: 1.0469 - val_accuracy: 0.6000
# Epoch 87/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.7853 - accuracy: 0.7010 - val_loss: 0.9665 - val_accuracy: 0.6200
# Epoch 88/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.8367 - accuracy: 0.6680 - val_loss: 1.0448 - val_accuracy: 0.6400
# Epoch 89/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.8386 - accuracy: 0.6750 - val_loss: 1.0833 - val_accuracy: 0.5400
# Epoch 90/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.8322 - accuracy: 0.6780 - val_loss: 1.0930 - val_accuracy: 0.5800
# Epoch 91/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.7771 - accuracy: 0.7000 - val_loss: 1.1088 - val_accuracy: 0.6400
# Epoch 92/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.7925 - accuracy: 0.7190 - val_loss: 1.1557 - val_accuracy: 0.5800
# Epoch 93/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7763 - accuracy: 0.7060 - val_loss: 1.1525 - val_accuracy: 0.6400
# Epoch 94/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.7686 - accuracy: 0.7030 - val_loss: 1.0804 - val_accuracy: 0.7000
# Epoch 95/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7866 - accuracy: 0.6870 - val_loss: 1.0247 - val_accuracy: 0.6400
# Epoch 96/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7619 - accuracy: 0.6890 - val_loss: 1.1229 - val_accuracy: 0.6600
# Epoch 97/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.7760 - accuracy: 0.7050 - val_loss: 1.0452 - val_accuracy: 0.6400
# Epoch 98/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7629 - accuracy: 0.7160 - val_loss: 1.0868 - val_accuracy: 0.6600
# Epoch 99/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7824 - accuracy: 0.7020 - val_loss: 1.0983 - val_accuracy: 0.6400
# Epoch 100/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7417 - accuracy: 0.7040 - val_loss: 1.2540 - val_accuracy: 0.6400
# Epoch 101/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.7944 - accuracy: 0.6900 - val_loss: 1.1035 - val_accuracy: 0.6600
# Epoch 102/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7576 - accuracy: 0.7060 - val_loss: 1.0084 - val_accuracy: 0.7000
# Epoch 103/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7869 - accuracy: 0.6830 - val_loss: 1.0415 - val_accuracy: 0.6400
# Epoch 104/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7711 - accuracy: 0.7070 - val_loss: 1.0263 - val_accuracy: 0.6400
# Epoch 105/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7344 - accuracy: 0.6960 - val_loss: 0.9603 - val_accuracy: 0.6800
# Epoch 106/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7265 - accuracy: 0.7160 - val_loss: 1.0128 - val_accuracy: 0.6200
# Epoch 107/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7531 - accuracy: 0.7030 - val_loss: 1.0816 - val_accuracy: 0.5600
# Epoch 108/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.7306 - accuracy: 0.7060 - val_loss: 1.1376 - val_accuracy: 0.4800
# Epoch 109/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.7308 - accuracy: 0.7170 - val_loss: 0.9779 - val_accuracy: 0.6800
# Epoch 110/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7376 - accuracy: 0.7070 - val_loss: 0.9557 - val_accuracy: 0.6600
# Epoch 111/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.7809 - accuracy: 0.6950 - val_loss: 0.9715 - val_accuracy: 0.6800
# Epoch 112/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6845 - accuracy: 0.7170 - val_loss: 1.0841 - val_accuracy: 0.6000
# Epoch 113/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.7231 - accuracy: 0.7280 - val_loss: 1.0723 - val_accuracy: 0.6400
# Epoch 114/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.7523 - accuracy: 0.7020 - val_loss: 1.0113 - val_accuracy: 0.6600
# Epoch 115/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.7606 - accuracy: 0.6930 - val_loss: 1.0742 - val_accuracy: 0.6400
# Epoch 116/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.7525 - accuracy: 0.7170 - val_loss: 1.0999 - val_accuracy: 0.6200
# Epoch 117/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7226 - accuracy: 0.7250 - val_loss: 1.1567 - val_accuracy: 0.5800
# Epoch 118/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7280 - accuracy: 0.7160 - val_loss: 1.1151 - val_accuracy: 0.5800
# Epoch 119/200
# 10/10 [==============================] - 2s 155ms/step - loss: 0.7652 - accuracy: 0.7200 - val_loss: 1.3676 - val_accuracy: 0.5400
# Epoch 120/200
# 10/10 [==============================] - 2s 157ms/step - loss: 0.7501 - accuracy: 0.7090 - val_loss: 1.1503 - val_accuracy: 0.6800
# Epoch 121/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.7753 - accuracy: 0.6940 - val_loss: 1.1579 - val_accuracy: 0.6200
# Epoch 122/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.7202 - accuracy: 0.7130 - val_loss: 1.1934 - val_accuracy: 0.6200
# Epoch 123/200
# 10/10 [==============================] - 2s 155ms/step - loss: 0.7211 - accuracy: 0.7250 - val_loss: 1.1061 - val_accuracy: 0.6000
# Epoch 124/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.7358 - accuracy: 0.7330 - val_loss: 1.1772 - val_accuracy: 0.6200
# Epoch 125/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7208 - accuracy: 0.7230 - val_loss: 1.0417 - val_accuracy: 0.6400
# Epoch 126/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7081 - accuracy: 0.7250 - val_loss: 0.9854 - val_accuracy: 0.6800
# Epoch 127/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.6806 - accuracy: 0.7300 - val_loss: 0.9621 - val_accuracy: 0.7400
# Epoch 128/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6886 - accuracy: 0.7220 - val_loss: 1.1258 - val_accuracy: 0.6200
# Epoch 129/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.7334 - accuracy: 0.7110 - val_loss: 1.0253 - val_accuracy: 0.6800
# Epoch 130/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.7589 - accuracy: 0.7030 - val_loss: 1.0190 - val_accuracy: 0.6800
# Epoch 131/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6913 - accuracy: 0.7130 - val_loss: 1.0658 - val_accuracy: 0.5800
# Epoch 132/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6976 - accuracy: 0.7430 - val_loss: 1.1441 - val_accuracy: 0.5400
# Epoch 133/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6943 - accuracy: 0.7270 - val_loss: 1.0203 - val_accuracy: 0.6000
# Epoch 134/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6959 - accuracy: 0.7160 - val_loss: 0.9172 - val_accuracy: 0.6800
# Epoch 135/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7446 - accuracy: 0.7020 - val_loss: 0.9372 - val_accuracy: 0.6400
# Epoch 136/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6963 - accuracy: 0.7350 - val_loss: 0.9885 - val_accuracy: 0.7000
# Epoch 137/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7298 - accuracy: 0.7290 - val_loss: 1.0767 - val_accuracy: 0.5600
# Epoch 138/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6408 - accuracy: 0.7560 - val_loss: 0.9909 - val_accuracy: 0.6000
# Epoch 139/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6981 - accuracy: 0.7430 - val_loss: 1.0500 - val_accuracy: 0.5800
# Epoch 140/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.7061 - accuracy: 0.7230 - val_loss: 1.2008 - val_accuracy: 0.5800
# Epoch 141/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.7076 - accuracy: 0.7180 - val_loss: 1.0361 - val_accuracy: 0.6600
# Epoch 142/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.7153 - accuracy: 0.7250 - val_loss: 1.1022 - val_accuracy: 0.6600
# Epoch 143/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6982 - accuracy: 0.7310 - val_loss: 1.1275 - val_accuracy: 0.6600
# Epoch 144/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6706 - accuracy: 0.7370 - val_loss: 1.2200 - val_accuracy: 0.6400
# Epoch 145/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6664 - accuracy: 0.7380 - val_loss: 1.1700 - val_accuracy: 0.6600
# Epoch 146/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6721 - accuracy: 0.7370 - val_loss: 1.0148 - val_accuracy: 0.6800
# Epoch 147/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6644 - accuracy: 0.7320 - val_loss: 0.9950 - val_accuracy: 0.6400
# Epoch 148/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6657 - accuracy: 0.7340 - val_loss: 1.1081 - val_accuracy: 0.6000
# Epoch 149/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6891 - accuracy: 0.7200 - val_loss: 1.1473 - val_accuracy: 0.6200
# Epoch 150/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6908 - accuracy: 0.7350 - val_loss: 1.2350 - val_accuracy: 0.6000
# Epoch 151/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6929 - accuracy: 0.7240 - val_loss: 1.3310 - val_accuracy: 0.5600
# Epoch 152/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6881 - accuracy: 0.7230 - val_loss: 1.0982 - val_accuracy: 0.6400
# Epoch 153/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7004 - accuracy: 0.7260 - val_loss: 0.9777 - val_accuracy: 0.6600
# Epoch 154/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6351 - accuracy: 0.7510 - val_loss: 1.0123 - val_accuracy: 0.6200
# Epoch 155/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7037 - accuracy: 0.7270 - val_loss: 0.9252 - val_accuracy: 0.7000
# Epoch 156/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6941 - accuracy: 0.7280 - val_loss: 0.9785 - val_accuracy: 0.6600
# Epoch 157/200
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6685 - accuracy: 0.7390 - val_loss: 0.9443 - val_accuracy: 0.6600
# Epoch 158/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.6330 - accuracy: 0.7450 - val_loss: 0.9756 - val_accuracy: 0.6200
# Epoch 159/200
# 10/10 [==============================] - 2s 161ms/step - loss: 0.6578 - accuracy: 0.7430 - val_loss: 0.9648 - val_accuracy: 0.6800
# Epoch 160/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6417 - accuracy: 0.7380 - val_loss: 1.1195 - val_accuracy: 0.6400
# Epoch 161/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6802 - accuracy: 0.7340 - val_loss: 1.0163 - val_accuracy: 0.7200
# Epoch 162/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6513 - accuracy: 0.7480 - val_loss: 1.0310 - val_accuracy: 0.6200
# Epoch 163/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6987 - accuracy: 0.7250 - val_loss: 0.9999 - val_accuracy: 0.6600
# Epoch 164/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6545 - accuracy: 0.7270 - val_loss: 0.9848 - val_accuracy: 0.6800
# Epoch 165/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.6687 - accuracy: 0.7420 - val_loss: 1.0523 - val_accuracy: 0.6200
# Epoch 166/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6571 - accuracy: 0.7310 - val_loss: 1.0354 - val_accuracy: 0.6400
# Epoch 167/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.6754 - accuracy: 0.7250 - val_loss: 1.0424 - val_accuracy: 0.6600
# Epoch 168/200
# 10/10 [==============================] - 1s 146ms/step - loss: 0.6539 - accuracy: 0.7370 - val_loss: 1.1243 - val_accuracy: 0.6800
# Epoch 169/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6630 - accuracy: 0.7470 - val_loss: 1.1336 - val_accuracy: 0.6600
# Epoch 170/200
# 10/10 [==============================] - 2s 154ms/step - loss: 0.6537 - accuracy: 0.7560 - val_loss: 1.0504 - val_accuracy: 0.6400
# Epoch 171/200
# 10/10 [==============================] - 2s 158ms/step - loss: 0.6196 - accuracy: 0.7520 - val_loss: 1.1290 - val_accuracy: 0.6000
# Epoch 172/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6573 - accuracy: 0.7310 - val_loss: 1.0292 - val_accuracy: 0.6400
# Epoch 173/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6563 - accuracy: 0.7290 - val_loss: 0.9142 - val_accuracy: 0.7200
# Epoch 174/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6384 - accuracy: 0.7350 - val_loss: 0.9348 - val_accuracy: 0.7200
# Epoch 175/200
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6542 - accuracy: 0.7370 - val_loss: 1.0172 - val_accuracy: 0.6400
# Epoch 176/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6692 - accuracy: 0.7530 - val_loss: 1.0446 - val_accuracy: 0.6800
# Epoch 177/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6336 - accuracy: 0.7490 - val_loss: 1.0324 - val_accuracy: 0.6600
# Epoch 178/200
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6477 - accuracy: 0.7500 - val_loss: 1.0235 - val_accuracy: 0.6400
# Epoch 179/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6210 - accuracy: 0.7570 - val_loss: 0.9514 - val_accuracy: 0.6600
# Epoch 180/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6372 - accuracy: 0.7450 - val_loss: 0.9040 - val_accuracy: 0.6800
# Epoch 181/200
# 10/10 [==============================] - 2s 146ms/step - loss: 0.6185 - accuracy: 0.7430 - val_loss: 1.0371 - val_accuracy: 0.6800
# Epoch 182/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6581 - accuracy: 0.7460 - val_loss: 1.0085 - val_accuracy: 0.6800
# Epoch 183/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6551 - accuracy: 0.7490 - val_loss: 0.9195 - val_accuracy: 0.6800
# Epoch 184/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6573 - accuracy: 0.7350 - val_loss: 0.9345 - val_accuracy: 0.7200
# Epoch 185/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6288 - accuracy: 0.7520 - val_loss: 0.9505 - val_accuracy: 0.6800
# Epoch 186/200
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6046 - accuracy: 0.7630 - val_loss: 1.0020 - val_accuracy: 0.6800
# Epoch 187/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6064 - accuracy: 0.7420 - val_loss: 1.0991 - val_accuracy: 0.6000
# Epoch 188/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6473 - accuracy: 0.7440 - val_loss: 0.9323 - val_accuracy: 0.7000
# Epoch 189/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6387 - accuracy: 0.7570 - val_loss: 1.2411 - val_accuracy: 0.6000
# Epoch 190/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6381 - accuracy: 0.7450 - val_loss: 1.0118 - val_accuracy: 0.6800
# Epoch 191/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6134 - accuracy: 0.7490 - val_loss: 0.9448 - val_accuracy: 0.6600
# Epoch 192/200
# 10/10 [==============================] - 2s 149ms/step - loss: 0.6219 - accuracy: 0.7330 - val_loss: 0.9950 - val_accuracy: 0.7000
# Epoch 193/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6371 - accuracy: 0.7460 - val_loss: 0.9286 - val_accuracy: 0.7200
# Epoch 194/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6275 - accuracy: 0.7490 - val_loss: 0.9966 - val_accuracy: 0.6600
# Epoch 195/200
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6686 - accuracy: 0.7400 - val_loss: 0.9406 - val_accuracy: 0.6800
# Epoch 196/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6069 - accuracy: 0.7550 - val_loss: 0.9265 - val_accuracy: 0.7200
# Epoch 197/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6368 - accuracy: 0.7480 - val_loss: 1.0736 - val_accuracy: 0.6800
# Epoch 198/200
# 10/10 [==============================] - 2s 148ms/step - loss: 0.6381 - accuracy: 0.7440 - val_loss: 0.9573 - val_accuracy: 0.6800
# Epoch 199/200
# 10/10 [==============================] - 1s 146ms/step - loss: 0.6391 - accuracy: 0.7540 - val_loss: 1.0142 - val_accuracy: 0.6800
# Epoch 200/200
# 10/10 [==============================] - 2s 147ms/step - loss: 0.6129 - accuracy: 0.7620 - val_loss: 1.1096 - val_accuracy: 0.6800

# %%
def plot_accuracy(history):
    acc = 'acc' if 'acc' in history else 'accuracy'
    val_acc = 'val_' + acc
    
    plt.plot(range(len(history[acc])), history[acc], color='b')
    plt.plot(range(len(history[val_acc])), history[val_acc], color='g')

    return hist.history[val_acc][-1]

plot_accuracy(hist.history)
# Out:
# 0.6800000071525574

# %% [markdown]
# Для проверки сохраняются веса сети:

# %%
aug_saved_model = os.path.join("models", "task_4_weights.h5")
# Создаём папку, куда сохраним результаты, если папки ещё нет
Path("models").mkdir(parents=True, exist_ok=True)
fashion_clf.save(aug_saved_model)

add_to_answer(
    "task_4",
    {
        "model_path": aug_saved_model,
        "fit_params": fit_params,
        "aug_params": aug_params,
    },
)

# %% [markdown]
# Любые попытки получить более точную модель не с помощью аугментации запрещены.
#
# ---
#
# ## Выбор подходящей модели машинного обучения
#
# Возьмём набор данных `wine`

# %%
wine_x, wine_y = load_wine(return_X_y=True)

x_train, x_test, y_train, y_test = train_test_split(wine_x, wine_y, test_size=0.2, random_state=123456)

# %% [markdown]
# ---
#
# #### Задание 5 (дополнительное).
#
# Подберите модель машинного обучения для решения задачи _регрессии_ на данных из датасета `wine`.
#
# Обучите выбранную модель, используя для обучения только данные `x_train`, `y_train`.
#
# Данные `x_test`, `y_test` можно использовать в обучении _только в качестве валидационных данных_.
#
# Метрика **MAE** (mean absolute error, средняя абсолютная ошибка) на **тестовых** данных (`x_test`, `y_test`) должна быть **меньше 0.1**.
#
# _За выполнение этого задания можно получить 1 дополнительный балл, но выполнять это задание не обязательно_

# %%
# Ваш код обучения модели
wine_regressor = CatBoostRegressor()
wine_regressor.fit(x_train, y_train)
# Out:
# Learning rate set to 0.030077
# 0:	learn: 0.7680978	total: 2.73ms	remaining: 2.73s
# 1:	learn: 0.7571127	total: 3.5ms	remaining: 1.75s
# 2:	learn: 0.7404547	total: 4.19ms	remaining: 1.39s
# 3:	learn: 0.7249261	total: 4.89ms	remaining: 1.22s
# 4:	learn: 0.7086484	total: 5.65ms	remaining: 1.12s
# 5:	learn: 0.6950904	total: 6.67ms	remaining: 1.1s
# 6:	learn: 0.6795655	total: 7.59ms	remaining: 1.08s
# 7:	learn: 0.6663547	total: 8.31ms	remaining: 1.03s
# 8:	learn: 0.6547126	total: 9.06ms	remaining: 998ms
# 9:	learn: 0.6398596	total: 9.89ms	remaining: 979ms
# 10:	learn: 0.6259143	total: 10.5ms	remaining: 948ms
# 11:	learn: 0.6110082	total: 11.2ms	remaining: 921ms
# 12:	learn: 0.5981388	total: 11.8ms	remaining: 895ms
# 13:	learn: 0.5866153	total: 12.4ms	remaining: 872ms
# 14:	learn: 0.5732196	total: 13ms	remaining: 855ms
# 15:	learn: 0.5606311	total: 13.6ms	remaining: 838ms
# 16:	learn: 0.5492812	total: 14.2ms	remaining: 822ms
# 17:	learn: 0.5383926	total: 14.9ms	remaining: 811ms
# 18:	learn: 0.5283829	total: 15.6ms	remaining: 807ms
# 19:	learn: 0.5176623	total: 16.2ms	remaining: 796ms
# 20:	learn: 0.5064810	total: 16.9ms	remaining: 787ms
# 21:	learn: 0.4946608	total: 17.5ms	remaining: 777ms
# 22:	learn: 0.4853986	total: 18.1ms	remaining: 768ms
# 23:	learn: 0.4746516	total: 18.7ms	remaining: 760ms
# 24:	learn: 0.4650363	total: 19.3ms	remaining: 753ms
# 25:	learn: 0.4558776	total: 19.9ms	remaining: 746ms
# 26:	learn: 0.4479708	total: 20.5ms	remaining: 740ms
# 27:	learn: 0.4381398	total: 21.1ms	remaining: 733ms
# 28:	learn: 0.4287852	total: 21.7ms	remaining: 726ms
# 29:	learn: 0.4194026	total: 22.3ms	remaining: 720ms
# 30:	learn: 0.4114279	total: 23ms	remaining: 718ms
# 31:	learn: 0.4031900	total: 23.6ms	remaining: 713ms
# 32:	learn: 0.3958938	total: 24.3ms	remaining: 711ms
# 33:	learn: 0.3892124	total: 25ms	remaining: 710ms
# 34:	learn: 0.3828312	total: 25.6ms	remaining: 706ms
# 35:	learn: 0.3758055	total: 26.2ms	remaining: 702ms
# 36:	learn: 0.3690318	total: 26.8ms	remaining: 697ms
# 37:	learn: 0.3627007	total: 27.4ms	remaining: 693ms
# 38:	learn: 0.3556797	total: 28ms	remaining: 689ms
# 39:	learn: 0.3484297	total: 28.6ms	remaining: 686ms
# 40:	learn: 0.3419476	total: 29.2ms	remaining: 683ms
# 41:	learn: 0.3357182	total: 29.8ms	remaining: 679ms
# 42:	learn: 0.3298323	total: 30.4ms	remaining: 676ms
# 43:	learn: 0.3234359	total: 31ms	remaining: 673ms
# 44:	learn: 0.3183791	total: 31.6ms	remaining: 670ms
# 45:	learn: 0.3116109	total: 32.1ms	remaining: 667ms
# 46:	learn: 0.3058263	total: 32.7ms	remaining: 663ms
# 47:	learn: 0.3000102	total: 33.5ms	remaining: 664ms
# 48:	learn: 0.2945841	total: 34.2ms	remaining: 663ms
# 49:	learn: 0.2897560	total: 34.8ms	remaining: 661ms
# 50:	learn: 0.2840499	total: 35.4ms	remaining: 658ms
# 51:	learn: 0.2786587	total: 36ms	remaining: 657ms
# 52:	learn: 0.2732254	total: 36.6ms	remaining: 654ms
# 53:	learn: 0.2674069	total: 37.3ms	remaining: 653ms
# 54:	learn: 0.2629197	total: 37.9ms	remaining: 651ms
# 55:	learn: 0.2586544	total: 38.5ms	remaining: 649ms
# 56:	learn: 0.2548454	total: 39.1ms	remaining: 646ms
# 57:	learn: 0.2497786	total: 39.6ms	remaining: 644ms
# 58:	learn: 0.2457637	total: 40.2ms	remaining: 641ms
# 59:	learn: 0.2408294	total: 40.8ms	remaining: 639ms
# 60:	learn: 0.2371109	total: 41.4ms	remaining: 638ms
# 61:	learn: 0.2325500	total: 42.1ms	remaining: 637ms
# 62:	learn: 0.2277681	total: 42.8ms	remaining: 637ms
# 63:	learn: 0.2237770	total: 43.5ms	remaining: 636ms
# 64:	learn: 0.2197939	total: 44.1ms	remaining: 634ms
# 65:	learn: 0.2167019	total: 44.7ms	remaining: 632ms
# 66:	learn: 0.2130535	total: 45.2ms	remaining: 630ms
# 67:	learn: 0.2089561	total: 45.8ms	remaining: 628ms
# 68:	learn: 0.2055980	total: 46.4ms	remaining: 627ms
# 69:	learn: 0.2027763	total: 47ms	remaining: 625ms
# 70:	learn: 0.1995682	total: 47.6ms	remaining: 623ms
# 71:	learn: 0.1959610	total: 48.2ms	remaining: 621ms
# 72:	learn: 0.1925218	total: 48.8ms	remaining: 620ms
# 73:	learn: 0.1895307	total: 49.4ms	remaining: 618ms
# 74:	learn: 0.1866582	total: 50ms	remaining: 617ms
# 75:	learn: 0.1835450	total: 50.9ms	remaining: 618ms
# 76:	learn: 0.1803723	total: 51.5ms	remaining: 618ms
# 77:	learn: 0.1779191	total: 52.4ms	remaining: 619ms
# 78:	learn: 0.1752712	total: 53ms	remaining: 618ms
# 79:	learn: 0.1733506	total: 53.6ms	remaining: 616ms
# 80:	learn: 0.1709553	total: 54.4ms	remaining: 617ms
# 81:	learn: 0.1681649	total: 55ms	remaining: 615ms
# 82:	learn: 0.1656738	total: 55.6ms	remaining: 614ms
# 83:	learn: 0.1633067	total: 56.2ms	remaining: 612ms
# 84:	learn: 0.1605452	total: 56.8ms	remaining: 612ms
# 85:	learn: 0.1584972	total: 57.4ms	remaining: 610ms
# 86:	learn: 0.1565209	total: 58ms	remaining: 609ms
# 87:	learn: 0.1541221	total: 58.6ms	remaining: 607ms
# 88:	learn: 0.1522083	total: 59.2ms	remaining: 606ms
# 89:	learn: 0.1505127	total: 59.9ms	remaining: 605ms
# 90:	learn: 0.1487464	total: 60.5ms	remaining: 605ms
# 91:	learn: 0.1464417	total: 61.1ms	remaining: 603ms
# 92:	learn: 0.1443076	total: 61.7ms	remaining: 602ms
# 93:	learn: 0.1423796	total: 62.3ms	remaining: 601ms
# 94:	learn: 0.1404668	total: 62.9ms	remaining: 599ms
# 95:	learn: 0.1387877	total: 63.5ms	remaining: 598ms
# 96:	learn: 0.1373809	total: 64.1ms	remaining: 597ms
# 97:	learn: 0.1356532	total: 64.8ms	remaining: 596ms
# 98:	learn: 0.1338400	total: 65.4ms	remaining: 595ms
# 99:	learn: 0.1321482	total: 66ms	remaining: 594ms
# 100:	learn: 0.1303887	total: 66.5ms	remaining: 592ms
# 101:	learn: 0.1287970	total: 67.1ms	remaining: 591ms
# 102:	learn: 0.1269937	total: 67.7ms	remaining: 590ms
# 103:	learn: 0.1257045	total: 68.3ms	remaining: 588ms
# 104:	learn: 0.1242179	total: 69ms	remaining: 588ms
# 105:	learn: 0.1224745	total: 69.7ms	remaining: 588ms
# 106:	learn: 0.1211287	total: 70.6ms	remaining: 589ms
# 107:	learn: 0.1197504	total: 71.7ms	remaining: 592ms
# 108:	learn: 0.1183682	total: 72.3ms	remaining: 591ms
# 109:	learn: 0.1171496	total: 72.9ms	remaining: 590ms
# 110:	learn: 0.1156317	total: 73.5ms	remaining: 588ms
# 111:	learn: 0.1143184	total: 74.2ms	remaining: 588ms
# 112:	learn: 0.1131670	total: 74.8ms	remaining: 587ms
# 113:	learn: 0.1116968	total: 75.4ms	remaining: 586ms
# 114:	learn: 0.1103885	total: 76ms	remaining: 585ms
# 115:	learn: 0.1093039	total: 76.6ms	remaining: 584ms
# 116:	learn: 0.1084383	total: 77.2ms	remaining: 582ms
# 117:	learn: 0.1072127	total: 77.8ms	remaining: 581ms
# 118:	learn: 0.1060402	total: 78.5ms	remaining: 581ms
# 119:	learn: 0.1051337	total: 79.1ms	remaining: 580ms
# 120:	learn: 0.1043805	total: 79.7ms	remaining: 579ms
# 121:	learn: 0.1035515	total: 80.3ms	remaining: 578ms
# 122:	learn: 0.1025728	total: 80.9ms	remaining: 577ms
# 123:	learn: 0.1016307	total: 81.5ms	remaining: 576ms
# 124:	learn: 0.1007652	total: 82.1ms	remaining: 575ms
# 125:	learn: 0.0997258	total: 82.7ms	remaining: 574ms
# 126:	learn: 0.0988971	total: 83.3ms	remaining: 573ms
# 127:	learn: 0.0979797	total: 83.9ms	remaining: 572ms
# 128:	learn: 0.0971953	total: 84.5ms	remaining: 571ms
# 129:	learn: 0.0964856	total: 85.1ms	remaining: 570ms
# 130:	learn: 0.0958251	total: 85.7ms	remaining: 569ms
# 131:	learn: 0.0950448	total: 86.3ms	remaining: 568ms
# 132:	learn: 0.0941737	total: 87ms	remaining: 567ms
# 133:	learn: 0.0935256	total: 87.6ms	remaining: 566ms
# 134:	learn: 0.0926036	total: 88.2ms	remaining: 565ms
# 135:	learn: 0.0919779	total: 88.8ms	remaining: 564ms
# 136:	learn: 0.0910789	total: 89.4ms	remaining: 563ms
# 137:	learn: 0.0902997	total: 90ms	remaining: 562ms
# 138:	learn: 0.0893651	total: 90.6ms	remaining: 561ms
# 139:	learn: 0.0887162	total: 91.1ms	remaining: 560ms
# 140:	learn: 0.0881292	total: 91.7ms	remaining: 559ms
# 141:	learn: 0.0875282	total: 92.3ms	remaining: 558ms
# 142:	learn: 0.0868606	total: 92.9ms	remaining: 557ms
# 143:	learn: 0.0863458	total: 93.5ms	remaining: 556ms
# 144:	learn: 0.0858377	total: 94.1ms	remaining: 555ms
# 145:	learn: 0.0853908	total: 94.7ms	remaining: 554ms
# 146:	learn: 0.0849731	total: 95.3ms	remaining: 553ms
# 147:	learn: 0.0843906	total: 96.1ms	remaining: 553ms
# 148:	learn: 0.0839237	total: 96.9ms	remaining: 553ms
# 149:	learn: 0.0831880	total: 97.5ms	remaining: 552ms
# 150:	learn: 0.0824979	total: 98.2ms	remaining: 552ms
# 151:	learn: 0.0820037	total: 98.8ms	remaining: 551ms
# 152:	learn: 0.0814957	total: 99.5ms	remaining: 551ms
# 153:	learn: 0.0808680	total: 100ms	remaining: 549ms
# 154:	learn: 0.0802001	total: 101ms	remaining: 549ms
# 155:	learn: 0.0797561	total: 101ms	remaining: 548ms
# 156:	learn: 0.0791451	total: 102ms	remaining: 547ms
# 157:	learn: 0.0785945	total: 103ms	remaining: 546ms
# 158:	learn: 0.0780913	total: 103ms	remaining: 545ms
# 159:	learn: 0.0774943	total: 104ms	remaining: 544ms
# 160:	learn: 0.0769941	total: 104ms	remaining: 543ms
# 161:	learn: 0.0765447	total: 105ms	remaining: 543ms
# 162:	learn: 0.0761968	total: 106ms	remaining: 542ms
# 163:	learn: 0.0758142	total: 106ms	remaining: 541ms
# 164:	learn: 0.0753350	total: 107ms	remaining: 540ms
# 165:	learn: 0.0750361	total: 107ms	remaining: 539ms
# 166:	learn: 0.0746977	total: 108ms	remaining: 538ms
# 167:	learn: 0.0743634	total: 108ms	remaining: 537ms
# 168:	learn: 0.0739800	total: 109ms	remaining: 536ms
# 169:	learn: 0.0735522	total: 110ms	remaining: 535ms
# 170:	learn: 0.0730481	total: 110ms	remaining: 535ms
# 171:	learn: 0.0725341	total: 111ms	remaining: 534ms
# 172:	learn: 0.0721351	total: 111ms	remaining: 533ms
# 173:	learn: 0.0716686	total: 112ms	remaining: 532ms
# 174:	learn: 0.0712721	total: 113ms	remaining: 531ms
# 175:	learn: 0.0709469	total: 113ms	remaining: 530ms
# 176:	learn: 0.0703755	total: 114ms	remaining: 530ms
# 177:	learn: 0.0700520	total: 115ms	remaining: 529ms
# 178:	learn: 0.0697173	total: 115ms	remaining: 529ms
# 179:	learn: 0.0694028	total: 116ms	remaining: 528ms
# 180:	learn: 0.0691193	total: 116ms	remaining: 527ms
# 181:	learn: 0.0687817	total: 117ms	remaining: 526ms
# 182:	learn: 0.0682117	total: 118ms	remaining: 525ms
# 183:	learn: 0.0679873	total: 118ms	remaining: 524ms
# 184:	learn: 0.0675804	total: 119ms	remaining: 523ms
# 185:	learn: 0.0673311	total: 119ms	remaining: 522ms
# 186:	learn: 0.0670805	total: 120ms	remaining: 521ms
# 187:	learn: 0.0667081	total: 120ms	remaining: 520ms
# 188:	learn: 0.0665407	total: 121ms	remaining: 519ms
# 189:	learn: 0.0661107	total: 122ms	remaining: 518ms
# 190:	learn: 0.0656950	total: 122ms	remaining: 518ms
# 191:	learn: 0.0653498	total: 123ms	remaining: 517ms
# 192:	learn: 0.0649737	total: 123ms	remaining: 516ms
# 193:	learn: 0.0646822	total: 124ms	remaining: 516ms
# 194:	learn: 0.0643853	total: 125ms	remaining: 515ms
# 195:	learn: 0.0640549	total: 125ms	remaining: 514ms
# 196:	learn: 0.0637765	total: 126ms	remaining: 513ms
# 197:	learn: 0.0632883	total: 126ms	remaining: 512ms
# 198:	learn: 0.0630286	total: 127ms	remaining: 511ms
# 199:	learn: 0.0628009	total: 128ms	remaining: 511ms
# 200:	learn: 0.0626164	total: 128ms	remaining: 510ms
# 201:	learn: 0.0624323	total: 129ms	remaining: 509ms
# 202:	learn: 0.0622600	total: 129ms	remaining: 508ms
# 203:	learn: 0.0621119	total: 130ms	remaining: 507ms
# 204:	learn: 0.0619073	total: 131ms	remaining: 506ms
# 205:	learn: 0.0616245	total: 131ms	remaining: 506ms
# 206:	learn: 0.0611509	total: 132ms	remaining: 505ms
# 207:	learn: 0.0610086	total: 132ms	remaining: 504ms
# 208:	learn: 0.0607097	total: 133ms	remaining: 504ms
# 209:	learn: 0.0604779	total: 134ms	remaining: 503ms
# 210:	learn: 0.0599778	total: 134ms	remaining: 502ms
# 211:	learn: 0.0595699	total: 135ms	remaining: 501ms
# 212:	learn: 0.0592821	total: 135ms	remaining: 500ms
# 213:	learn: 0.0591054	total: 136ms	remaining: 499ms
# 214:	learn: 0.0588626	total: 137ms	remaining: 499ms
# 215:	learn: 0.0586578	total: 137ms	remaining: 498ms
# 216:	learn: 0.0584064	total: 138ms	remaining: 497ms
# 217:	learn: 0.0581658	total: 138ms	remaining: 496ms
# 218:	learn: 0.0578793	total: 139ms	remaining: 495ms
# 219:	learn: 0.0577086	total: 139ms	remaining: 494ms
# 220:	learn: 0.0575029	total: 140ms	remaining: 494ms
# 221:	learn: 0.0570695	total: 141ms	remaining: 493ms
# 222:	learn: 0.0568544	total: 141ms	remaining: 493ms
# 223:	learn: 0.0565337	total: 142ms	remaining: 492ms
# 224:	learn: 0.0563640	total: 142ms	remaining: 491ms
# 225:	learn: 0.0562113	total: 143ms	remaining: 490ms
# 226:	learn: 0.0557881	total: 144ms	remaining: 489ms
# 227:	learn: 0.0555818	total: 144ms	remaining: 489ms
# 228:	learn: 0.0552889	total: 145ms	remaining: 488ms
# 229:	learn: 0.0550758	total: 146ms	remaining: 487ms
# 230:	learn: 0.0549572	total: 146ms	remaining: 486ms
# 231:	learn: 0.0548784	total: 147ms	remaining: 486ms
# 232:	learn: 0.0545362	total: 147ms	remaining: 485ms
# 233:	learn: 0.0544241	total: 148ms	remaining: 484ms
# 234:	learn: 0.0542858	total: 149ms	remaining: 483ms
# 235:	learn: 0.0541605	total: 149ms	remaining: 483ms
# 236:	learn: 0.0540418	total: 150ms	remaining: 482ms
# 237:	learn: 0.0538648	total: 150ms	remaining: 482ms
# 238:	learn: 0.0536314	total: 151ms	remaining: 482ms
# 239:	learn: 0.0535067	total: 152ms	remaining: 481ms
# 240:	learn: 0.0532755	total: 152ms	remaining: 480ms
# 241:	learn: 0.0531084	total: 153ms	remaining: 479ms
# 242:	learn: 0.0529392	total: 154ms	remaining: 479ms
# 243:	learn: 0.0526572	total: 154ms	remaining: 478ms
# 244:	learn: 0.0525010	total: 155ms	remaining: 477ms
# 245:	learn: 0.0522643	total: 155ms	remaining: 477ms
# 246:	learn: 0.0521899	total: 156ms	remaining: 476ms
# 247:	learn: 0.0520160	total: 157ms	remaining: 475ms
# 248:	learn: 0.0519229	total: 157ms	remaining: 474ms
# 249:	learn: 0.0517628	total: 158ms	remaining: 474ms
# 250:	learn: 0.0516709	total: 158ms	remaining: 473ms
# 251:	learn: 0.0515041	total: 159ms	remaining: 472ms
# 252:	learn: 0.0513683	total: 160ms	remaining: 472ms
# 253:	learn: 0.0512287	total: 160ms	remaining: 471ms
# 254:	learn: 0.0509639	total: 161ms	remaining: 470ms
# 255:	learn: 0.0508420	total: 162ms	remaining: 470ms
# 256:	learn: 0.0507502	total: 162ms	remaining: 469ms
# 257:	learn: 0.0505456	total: 163ms	remaining: 468ms
# 258:	learn: 0.0503016	total: 163ms	remaining: 467ms
# 259:	learn: 0.0500914	total: 164ms	remaining: 467ms
# 260:	learn: 0.0498653	total: 165ms	remaining: 466ms
# 261:	learn: 0.0496262	total: 165ms	remaining: 465ms
# 262:	learn: 0.0493915	total: 166ms	remaining: 464ms
# 263:	learn: 0.0491994	total: 167ms	remaining: 464ms
# 264:	learn: 0.0490743	total: 167ms	remaining: 464ms
# 265:	learn: 0.0489429	total: 168ms	remaining: 463ms
# 266:	learn: 0.0488382	total: 169ms	remaining: 463ms
# 267:	learn: 0.0487340	total: 169ms	remaining: 462ms
# 268:	learn: 0.0486127	total: 170ms	remaining: 461ms
# 269:	learn: 0.0484992	total: 170ms	remaining: 461ms
# 270:	learn: 0.0483796	total: 171ms	remaining: 460ms
# 271:	learn: 0.0482057	total: 171ms	remaining: 459ms
# 272:	learn: 0.0480835	total: 172ms	remaining: 458ms
# 273:	learn: 0.0479667	total: 173ms	remaining: 457ms
# 274:	learn: 0.0477763	total: 173ms	remaining: 457ms
# 275:	learn: 0.0476724	total: 174ms	remaining: 456ms
# 276:	learn: 0.0475424	total: 174ms	remaining: 455ms
# 277:	learn: 0.0472339	total: 175ms	remaining: 454ms
# 278:	learn: 0.0470476	total: 176ms	remaining: 454ms
# 279:	learn: 0.0469992	total: 176ms	remaining: 453ms
# 280:	learn: 0.0466812	total: 177ms	remaining: 453ms
# 281:	learn: 0.0465790	total: 177ms	remaining: 452ms
# 282:	learn: 0.0464304	total: 178ms	remaining: 451ms
# 283:	learn: 0.0462999	total: 179ms	remaining: 451ms
# 284:	learn: 0.0460554	total: 179ms	remaining: 450ms
# 285:	learn: 0.0458894	total: 180ms	remaining: 449ms
# 286:	learn: 0.0456674	total: 181ms	remaining: 449ms
# 287:	learn: 0.0455240	total: 181ms	remaining: 448ms
# 288:	learn: 0.0453482	total: 182ms	remaining: 448ms
# 289:	learn: 0.0449924	total: 183ms	remaining: 448ms
# 290:	learn: 0.0448410	total: 184ms	remaining: 448ms
# 291:	learn: 0.0445780	total: 185ms	remaining: 448ms
# 292:	learn: 0.0444588	total: 185ms	remaining: 447ms
# 293:	learn: 0.0442628	total: 186ms	remaining: 447ms
# 294:	learn: 0.0440144	total: 187ms	remaining: 447ms
# 295:	learn: 0.0438668	total: 188ms	remaining: 446ms
# 296:	learn: 0.0438273	total: 188ms	remaining: 446ms
# 297:	learn: 0.0435667	total: 189ms	remaining: 445ms
# 298:	learn: 0.0435327	total: 190ms	remaining: 445ms
# 299:	learn: 0.0434930	total: 190ms	remaining: 444ms
# 300:	learn: 0.0434572	total: 191ms	remaining: 444ms
# 301:	learn: 0.0433986	total: 192ms	remaining: 443ms
# 302:	learn: 0.0433574	total: 193ms	remaining: 443ms
# 303:	learn: 0.0433078	total: 193ms	remaining: 442ms
# 304:	learn: 0.0430230	total: 194ms	remaining: 442ms
# 305:	learn: 0.0428039	total: 195ms	remaining: 442ms
# 306:	learn: 0.0427748	total: 196ms	remaining: 442ms
# 307:	learn: 0.0426794	total: 196ms	remaining: 441ms
# 308:	learn: 0.0425463	total: 197ms	remaining: 441ms
# 309:	learn: 0.0422602	total: 198ms	remaining: 441ms
# 310:	learn: 0.0421770	total: 199ms	remaining: 441ms
# 311:	learn: 0.0419480	total: 200ms	remaining: 441ms
# 312:	learn: 0.0418230	total: 201ms	remaining: 440ms
# 313:	learn: 0.0416822	total: 201ms	remaining: 440ms
# 314:	learn: 0.0414250	total: 202ms	remaining: 439ms
# 315:	learn: 0.0412142	total: 203ms	remaining: 439ms
# 316:	learn: 0.0410823	total: 204ms	remaining: 439ms
# 317:	learn: 0.0410512	total: 204ms	remaining: 438ms
# 318:	learn: 0.0409704	total: 205ms	remaining: 438ms
# 319:	learn: 0.0409337	total: 206ms	remaining: 437ms
# 320:	learn: 0.0407059	total: 206ms	remaining: 436ms
# 321:	learn: 0.0406671	total: 207ms	remaining: 436ms
# 322:	learn: 0.0405001	total: 208ms	remaining: 435ms
# 323:	learn: 0.0402303	total: 208ms	remaining: 434ms
# 324:	learn: 0.0399242	total: 209ms	remaining: 435ms
# 325:	learn: 0.0397858	total: 210ms	remaining: 434ms
# 326:	learn: 0.0397258	total: 211ms	remaining: 434ms
# 327:	learn: 0.0395081	total: 211ms	remaining: 433ms
# 328:	learn: 0.0394772	total: 212ms	remaining: 433ms
# 329:	learn: 0.0394293	total: 213ms	remaining: 432ms
# 330:	learn: 0.0391941	total: 213ms	remaining: 432ms
# 331:	learn: 0.0390374	total: 214ms	remaining: 431ms
# 332:	learn: 0.0387272	total: 215ms	remaining: 431ms
# 333:	learn: 0.0386526	total: 216ms	remaining: 430ms
# 334:	learn: 0.0385811	total: 217ms	remaining: 430ms
# 335:	learn: 0.0385018	total: 217ms	remaining: 429ms
# 336:	learn: 0.0382679	total: 218ms	remaining: 429ms
# 337:	learn: 0.0380422	total: 219ms	remaining: 428ms
# 338:	learn: 0.0379576	total: 219ms	remaining: 427ms
# 339:	learn: 0.0379324	total: 220ms	remaining: 427ms
# 340:	learn: 0.0376752	total: 221ms	remaining: 427ms
# 341:	learn: 0.0376028	total: 222ms	remaining: 427ms
# 342:	learn: 0.0375329	total: 223ms	remaining: 426ms
# 343:	learn: 0.0373356	total: 223ms	remaining: 426ms
# 344:	learn: 0.0371549	total: 224ms	remaining: 425ms
# 345:	learn: 0.0370002	total: 224ms	remaining: 424ms
# 346:	learn: 0.0368064	total: 225ms	remaining: 423ms
# 347:	learn: 0.0367727	total: 226ms	remaining: 423ms
# 348:	learn: 0.0365894	total: 226ms	remaining: 422ms
# 349:	learn: 0.0364105	total: 227ms	remaining: 421ms
# 350:	learn: 0.0363866	total: 227ms	remaining: 420ms
# 351:	learn: 0.0362478	total: 228ms	remaining: 419ms
# 352:	learn: 0.0360563	total: 228ms	remaining: 419ms
# 353:	learn: 0.0359517	total: 229ms	remaining: 418ms
# 354:	learn: 0.0357546	total: 230ms	remaining: 417ms
# 355:	learn: 0.0357314	total: 230ms	remaining: 417ms
# 356:	learn: 0.0357086	total: 231ms	remaining: 416ms
# 357:	learn: 0.0354300	total: 232ms	remaining: 416ms
# 358:	learn: 0.0353915	total: 232ms	remaining: 415ms
# 359:	learn: 0.0353664	total: 233ms	remaining: 414ms
# 360:	learn: 0.0351874	total: 233ms	remaining: 413ms
# 361:	learn: 0.0351654	total: 234ms	remaining: 412ms
# 362:	learn: 0.0350432	total: 235ms	remaining: 412ms
# 363:	learn: 0.0349200	total: 235ms	remaining: 411ms
# 364:	learn: 0.0348295	total: 236ms	remaining: 410ms
# 365:	learn: 0.0345954	total: 236ms	remaining: 409ms
# 366:	learn: 0.0344337	total: 237ms	remaining: 409ms
# 367:	learn: 0.0342860	total: 238ms	remaining: 408ms
# 368:	learn: 0.0342225	total: 238ms	remaining: 407ms
# 369:	learn: 0.0341178	total: 239ms	remaining: 407ms
# 370:	learn: 0.0339284	total: 239ms	remaining: 406ms
# 371:	learn: 0.0338973	total: 240ms	remaining: 405ms
# 372:	learn: 0.0336485	total: 241ms	remaining: 404ms
# 373:	learn: 0.0335656	total: 241ms	remaining: 404ms
# 374:	learn: 0.0334888	total: 242ms	remaining: 403ms
# 375:	learn: 0.0333235	total: 242ms	remaining: 402ms
# 376:	learn: 0.0331294	total: 243ms	remaining: 401ms
# 377:	learn: 0.0329349	total: 243ms	remaining: 401ms
# 378:	learn: 0.0328476	total: 244ms	remaining: 400ms
# 379:	learn: 0.0326697	total: 245ms	remaining: 399ms
# 380:	learn: 0.0326121	total: 245ms	remaining: 398ms
# 381:	learn: 0.0325890	total: 246ms	remaining: 398ms
# 382:	learn: 0.0324369	total: 247ms	remaining: 397ms
# 383:	learn: 0.0324055	total: 247ms	remaining: 396ms
# 384:	learn: 0.0322365	total: 248ms	remaining: 396ms
# 385:	learn: 0.0321165	total: 248ms	remaining: 395ms
# 386:	learn: 0.0319347	total: 249ms	remaining: 394ms
# 387:	learn: 0.0317805	total: 250ms	remaining: 394ms
# 388:	learn: 0.0316732	total: 250ms	remaining: 393ms
# 389:	learn: 0.0315007	total: 251ms	remaining: 393ms
# 390:	learn: 0.0314696	total: 252ms	remaining: 392ms
# 391:	learn: 0.0313300	total: 252ms	remaining: 391ms
# 392:	learn: 0.0313024	total: 253ms	remaining: 391ms
# 393:	learn: 0.0312839	total: 253ms	remaining: 390ms
# 394:	learn: 0.0311343	total: 254ms	remaining: 389ms
# 395:	learn: 0.0309891	total: 255ms	remaining: 388ms
# 396:	learn: 0.0309598	total: 255ms	remaining: 388ms
# 397:	learn: 0.0309316	total: 256ms	remaining: 387ms
# 398:	learn: 0.0309090	total: 256ms	remaining: 386ms
# 399:	learn: 0.0308174	total: 257ms	remaining: 386ms
# 400:	learn: 0.0307560	total: 258ms	remaining: 385ms
# 401:	learn: 0.0307324	total: 258ms	remaining: 384ms
# 402:	learn: 0.0305754	total: 259ms	remaining: 383ms
# 403:	learn: 0.0305125	total: 259ms	remaining: 383ms
# 404:	learn: 0.0303875	total: 260ms	remaining: 382ms
# 405:	learn: 0.0301870	total: 261ms	remaining: 381ms
# 406:	learn: 0.0300853	total: 261ms	remaining: 381ms
# 407:	learn: 0.0299596	total: 262ms	remaining: 380ms
# 408:	learn: 0.0298530	total: 262ms	remaining: 379ms
# 409:	learn: 0.0297873	total: 263ms	remaining: 378ms
# 410:	learn: 0.0296945	total: 264ms	remaining: 378ms
# 411:	learn: 0.0295480	total: 264ms	remaining: 377ms
# 412:	learn: 0.0294606	total: 265ms	remaining: 376ms
# 413:	learn: 0.0293747	total: 265ms	remaining: 376ms
# 414:	learn: 0.0293586	total: 266ms	remaining: 375ms
# 415:	learn: 0.0291974	total: 267ms	remaining: 375ms
# 416:	learn: 0.0290239	total: 267ms	remaining: 374ms
# 417:	learn: 0.0289363	total: 268ms	remaining: 373ms
# 418:	learn: 0.0288014	total: 269ms	remaining: 372ms
# 419:	learn: 0.0286927	total: 269ms	remaining: 372ms
# 420:	learn: 0.0286759	total: 270ms	remaining: 371ms
# 421:	learn: 0.0286540	total: 270ms	remaining: 370ms
# 422:	learn: 0.0285169	total: 271ms	remaining: 369ms
# 423:	learn: 0.0284977	total: 271ms	remaining: 369ms
# 424:	learn: 0.0284778	total: 272ms	remaining: 368ms
# 425:	learn: 0.0283878	total: 272ms	remaining: 367ms
# 426:	learn: 0.0283279	total: 273ms	remaining: 366ms
# 427:	learn: 0.0281932	total: 274ms	remaining: 366ms
# 428:	learn: 0.0281418	total: 274ms	remaining: 365ms
# 429:	learn: 0.0280420	total: 275ms	remaining: 365ms
# 430:	learn: 0.0279543	total: 276ms	remaining: 364ms
# 431:	learn: 0.0278294	total: 276ms	remaining: 363ms
# 432:	learn: 0.0277012	total: 277ms	remaining: 363ms
# 433:	learn: 0.0275829	total: 278ms	remaining: 362ms
# 434:	learn: 0.0275170	total: 278ms	remaining: 361ms
# 435:	learn: 0.0273471	total: 279ms	remaining: 361ms
# 436:	learn: 0.0273264	total: 279ms	remaining: 360ms
# 437:	learn: 0.0272751	total: 280ms	remaining: 359ms
# 438:	learn: 0.0271233	total: 281ms	remaining: 359ms
# 439:	learn: 0.0269928	total: 281ms	remaining: 358ms
# 440:	learn: 0.0269104	total: 282ms	remaining: 357ms
# 441:	learn: 0.0267855	total: 282ms	remaining: 356ms
# 442:	learn: 0.0266686	total: 283ms	remaining: 356ms
# 443:	learn: 0.0265656	total: 284ms	remaining: 355ms
# 444:	learn: 0.0264348	total: 284ms	remaining: 355ms
# 445:	learn: 0.0264133	total: 285ms	remaining: 354ms
# 446:	learn: 0.0263316	total: 286ms	remaining: 353ms
# 447:	learn: 0.0263137	total: 286ms	remaining: 353ms
# 448:	learn: 0.0261985	total: 287ms	remaining: 352ms
# 449:	learn: 0.0261780	total: 287ms	remaining: 351ms
# 450:	learn: 0.0261580	total: 288ms	remaining: 350ms
# 451:	learn: 0.0260312	total: 289ms	remaining: 350ms
# 452:	learn: 0.0258832	total: 289ms	remaining: 349ms
# 453:	learn: 0.0257984	total: 290ms	remaining: 348ms
# 454:	learn: 0.0256652	total: 290ms	remaining: 348ms
# 455:	learn: 0.0255210	total: 291ms	remaining: 347ms
# 456:	learn: 0.0254053	total: 292ms	remaining: 346ms
# 457:	learn: 0.0253262	total: 292ms	remaining: 346ms
# 458:	learn: 0.0252710	total: 293ms	remaining: 345ms
# 459:	learn: 0.0252442	total: 294ms	remaining: 345ms
# 460:	learn: 0.0251822	total: 294ms	remaining: 344ms
# 461:	learn: 0.0251669	total: 295ms	remaining: 343ms
# 462:	learn: 0.0250785	total: 295ms	remaining: 343ms
# 463:	learn: 0.0249540	total: 296ms	remaining: 342ms
# 464:	learn: 0.0249397	total: 297ms	remaining: 341ms
# 465:	learn: 0.0248379	total: 297ms	remaining: 341ms
# 466:	learn: 0.0248197	total: 298ms	remaining: 340ms
# 467:	learn: 0.0247737	total: 298ms	remaining: 339ms
# 468:	learn: 0.0246692	total: 299ms	remaining: 338ms
# 469:	learn: 0.0245747	total: 300ms	remaining: 338ms
# 470:	learn: 0.0245207	total: 300ms	remaining: 337ms
# 471:	learn: 0.0245079	total: 301ms	remaining: 336ms
# 472:	learn: 0.0244485	total: 301ms	remaining: 336ms
# 473:	learn: 0.0244213	total: 302ms	remaining: 335ms
# 474:	learn: 0.0244055	total: 303ms	remaining: 334ms
# 475:	learn: 0.0243396	total: 303ms	remaining: 334ms
# 476:	learn: 0.0241709	total: 304ms	remaining: 333ms
# 477:	learn: 0.0240618	total: 304ms	remaining: 332ms
# 478:	learn: 0.0239812	total: 305ms	remaining: 332ms
# 479:	learn: 0.0239106	total: 306ms	remaining: 331ms
# 480:	learn: 0.0238646	total: 306ms	remaining: 330ms
# 481:	learn: 0.0237880	total: 307ms	remaining: 330ms
# 482:	learn: 0.0237172	total: 307ms	remaining: 329ms
# 483:	learn: 0.0236871	total: 308ms	remaining: 328ms
# 484:	learn: 0.0236636	total: 309ms	remaining: 328ms
# 485:	learn: 0.0235797	total: 309ms	remaining: 327ms
# 486:	learn: 0.0235299	total: 310ms	remaining: 326ms
# 487:	learn: 0.0235186	total: 310ms	remaining: 326ms
# 488:	learn: 0.0234671	total: 311ms	remaining: 325ms
# 489:	learn: 0.0234227	total: 312ms	remaining: 324ms
# 490:	learn: 0.0234077	total: 312ms	remaining: 324ms
# 491:	learn: 0.0233054	total: 313ms	remaining: 323ms
# 492:	learn: 0.0232927	total: 313ms	remaining: 322ms
# 493:	learn: 0.0232801	total: 314ms	remaining: 322ms
# 494:	learn: 0.0232458	total: 314ms	remaining: 321ms
# 495:	learn: 0.0231272	total: 315ms	remaining: 320ms
# 496:	learn: 0.0231153	total: 316ms	remaining: 319ms
# 497:	learn: 0.0230357	total: 316ms	remaining: 319ms
# 498:	learn: 0.0230010	total: 317ms	remaining: 318ms
# 499:	learn: 0.0228783	total: 317ms	remaining: 317ms
# 500:	learn: 0.0227633	total: 318ms	remaining: 317ms
# 501:	learn: 0.0226456	total: 319ms	remaining: 316ms
# 502:	learn: 0.0226323	total: 319ms	remaining: 315ms
# 503:	learn: 0.0225305	total: 320ms	remaining: 315ms
# 504:	learn: 0.0223951	total: 321ms	remaining: 314ms
# 505:	learn: 0.0223302	total: 321ms	remaining: 313ms
# 506:	learn: 0.0222108	total: 322ms	remaining: 313ms
# 507:	learn: 0.0221531	total: 322ms	remaining: 312ms
# 508:	learn: 0.0221012	total: 323ms	remaining: 311ms
# 509:	learn: 0.0220791	total: 323ms	remaining: 311ms
# 510:	learn: 0.0220094	total: 324ms	remaining: 310ms
# 511:	learn: 0.0219300	total: 325ms	remaining: 309ms
# 512:	learn: 0.0218434	total: 325ms	remaining: 309ms
# 513:	learn: 0.0217721	total: 326ms	remaining: 308ms
# 514:	learn: 0.0217573	total: 326ms	remaining: 307ms
# 515:	learn: 0.0216268	total: 327ms	remaining: 307ms
# 516:	learn: 0.0215316	total: 328ms	remaining: 306ms
# 517:	learn: 0.0215204	total: 328ms	remaining: 305ms
# 518:	learn: 0.0214838	total: 329ms	remaining: 305ms
# 519:	learn: 0.0213880	total: 329ms	remaining: 304ms
# 520:	learn: 0.0212672	total: 330ms	remaining: 303ms
# 521:	learn: 0.0211417	total: 331ms	remaining: 303ms
# 522:	learn: 0.0211097	total: 331ms	remaining: 302ms
# 523:	learn: 0.0210110	total: 332ms	remaining: 301ms
# 524:	learn: 0.0209234	total: 332ms	remaining: 301ms
# 525:	learn: 0.0208925	total: 333ms	remaining: 300ms
# 526:	learn: 0.0207630	total: 334ms	remaining: 300ms
# 527:	learn: 0.0206911	total: 335ms	remaining: 299ms
# 528:	learn: 0.0206794	total: 335ms	remaining: 299ms
# 529:	learn: 0.0206694	total: 336ms	remaining: 298ms
# 530:	learn: 0.0205584	total: 336ms	remaining: 297ms
# 531:	learn: 0.0204661	total: 337ms	remaining: 297ms
# 532:	learn: 0.0203637	total: 338ms	remaining: 296ms
# 533:	learn: 0.0203134	total: 339ms	remaining: 295ms
# 534:	learn: 0.0202423	total: 339ms	remaining: 295ms
# 535:	learn: 0.0202117	total: 340ms	remaining: 294ms
# 536:	learn: 0.0201218	total: 341ms	remaining: 294ms
# 537:	learn: 0.0200165	total: 341ms	remaining: 293ms
# 538:	learn: 0.0199196	total: 342ms	remaining: 292ms
# 539:	learn: 0.0198397	total: 342ms	remaining: 292ms
# 540:	learn: 0.0198209	total: 343ms	remaining: 291ms
# 541:	learn: 0.0197330	total: 343ms	remaining: 290ms
# 542:	learn: 0.0196599	total: 344ms	remaining: 290ms
# 543:	learn: 0.0196511	total: 345ms	remaining: 289ms
# 544:	learn: 0.0196091	total: 345ms	remaining: 288ms
# 545:	learn: 0.0194869	total: 346ms	remaining: 288ms
# 546:	learn: 0.0193903	total: 346ms	remaining: 287ms
# 547:	learn: 0.0193813	total: 347ms	remaining: 286ms
# 548:	learn: 0.0192887	total: 348ms	remaining: 286ms
# 549:	learn: 0.0192039	total: 348ms	remaining: 285ms
# 550:	learn: 0.0191943	total: 349ms	remaining: 284ms
# 551:	learn: 0.0191842	total: 349ms	remaining: 284ms
# 552:	learn: 0.0190898	total: 350ms	remaining: 283ms
# 553:	learn: 0.0189525	total: 351ms	remaining: 282ms
# 554:	learn: 0.0189260	total: 351ms	remaining: 282ms
# 555:	learn: 0.0188687	total: 352ms	remaining: 281ms
# 556:	learn: 0.0188130	total: 352ms	remaining: 280ms
# 557:	learn: 0.0187823	total: 353ms	remaining: 280ms
# 558:	learn: 0.0186629	total: 354ms	remaining: 279ms
# 559:	learn: 0.0185749	total: 354ms	remaining: 278ms
# 560:	learn: 0.0184823	total: 355ms	remaining: 278ms
# 561:	learn: 0.0184440	total: 355ms	remaining: 277ms
# 562:	learn: 0.0183673	total: 356ms	remaining: 276ms
# 563:	learn: 0.0183390	total: 357ms	remaining: 276ms
# 564:	learn: 0.0182874	total: 357ms	remaining: 275ms
# 565:	learn: 0.0182042	total: 358ms	remaining: 274ms
# 566:	learn: 0.0181146	total: 358ms	remaining: 274ms
# 567:	learn: 0.0180260	total: 359ms	remaining: 273ms
# 568:	learn: 0.0179451	total: 360ms	remaining: 272ms
# 569:	learn: 0.0178777	total: 360ms	remaining: 272ms
# 570:	learn: 0.0177606	total: 361ms	remaining: 271ms
# 571:	learn: 0.0176936	total: 362ms	remaining: 271ms
# 572:	learn: 0.0176493	total: 363ms	remaining: 270ms
# 573:	learn: 0.0175774	total: 364ms	remaining: 270ms
# 574:	learn: 0.0174874	total: 364ms	remaining: 269ms
# 575:	learn: 0.0174140	total: 365ms	remaining: 269ms
# 576:	learn: 0.0173772	total: 366ms	remaining: 268ms
# 577:	learn: 0.0173121	total: 366ms	remaining: 268ms
# 578:	learn: 0.0172259	total: 367ms	remaining: 267ms
# 579:	learn: 0.0171777	total: 368ms	remaining: 266ms
# 580:	learn: 0.0171616	total: 368ms	remaining: 266ms
# 581:	learn: 0.0171487	total: 369ms	remaining: 265ms
# 582:	learn: 0.0170974	total: 370ms	remaining: 265ms
# 583:	learn: 0.0170534	total: 370ms	remaining: 264ms
# 584:	learn: 0.0169604	total: 371ms	remaining: 263ms
# 585:	learn: 0.0169229	total: 372ms	remaining: 263ms
# 586:	learn: 0.0168666	total: 373ms	remaining: 262ms
# 587:	learn: 0.0168512	total: 373ms	remaining: 262ms
# 588:	learn: 0.0167864	total: 374ms	remaining: 261ms
# 589:	learn: 0.0167529	total: 375ms	remaining: 260ms
# 590:	learn: 0.0167294	total: 376ms	remaining: 260ms
# 591:	learn: 0.0167002	total: 376ms	remaining: 259ms
# 592:	learn: 0.0166073	total: 377ms	remaining: 259ms
# 593:	learn: 0.0165970	total: 378ms	remaining: 258ms
# 594:	learn: 0.0165351	total: 379ms	remaining: 258ms
# 595:	learn: 0.0164511	total: 380ms	remaining: 257ms
# 596:	learn: 0.0163795	total: 381ms	remaining: 257ms
# 597:	learn: 0.0163713	total: 382ms	remaining: 257ms
# 598:	learn: 0.0162782	total: 383ms	remaining: 256ms
# 599:	learn: 0.0161635	total: 383ms	remaining: 256ms
# 600:	learn: 0.0161451	total: 384ms	remaining: 255ms
# 601:	learn: 0.0160655	total: 385ms	remaining: 255ms
# 602:	learn: 0.0160191	total: 386ms	remaining: 254ms
# 603:	learn: 0.0159713	total: 386ms	remaining: 253ms
# 604:	learn: 0.0158778	total: 387ms	remaining: 253ms
# 605:	learn: 0.0158164	total: 388ms	remaining: 252ms
# 606:	learn: 0.0157532	total: 388ms	remaining: 251ms
# 607:	learn: 0.0157315	total: 389ms	remaining: 251ms
# 608:	learn: 0.0156568	total: 390ms	remaining: 250ms
# 609:	learn: 0.0156340	total: 391ms	remaining: 250ms
# 610:	learn: 0.0156247	total: 391ms	remaining: 249ms
# 611:	learn: 0.0155152	total: 392ms	remaining: 249ms
# 612:	learn: 0.0154815	total: 393ms	remaining: 248ms
# 613:	learn: 0.0153721	total: 393ms	remaining: 247ms
# 614:	learn: 0.0153141	total: 394ms	remaining: 247ms
# 615:	learn: 0.0152496	total: 395ms	remaining: 246ms
# 616:	learn: 0.0152196	total: 395ms	remaining: 245ms
# 617:	learn: 0.0151376	total: 396ms	remaining: 245ms
# 618:	learn: 0.0150898	total: 397ms	remaining: 244ms
# 619:	learn: 0.0150820	total: 397ms	remaining: 244ms
# 620:	learn: 0.0150026	total: 398ms	remaining: 243ms
# 621:	learn: 0.0149418	total: 398ms	remaining: 242ms
# 622:	learn: 0.0148621	total: 399ms	remaining: 241ms
# 623:	learn: 0.0148079	total: 400ms	remaining: 241ms
# 624:	learn: 0.0147662	total: 400ms	remaining: 240ms
# 625:	learn: 0.0147439	total: 401ms	remaining: 240ms
# 626:	learn: 0.0147206	total: 401ms	remaining: 239ms
# 627:	learn: 0.0146606	total: 402ms	remaining: 238ms
# 628:	learn: 0.0146531	total: 403ms	remaining: 238ms
# 629:	learn: 0.0146432	total: 403ms	remaining: 237ms
# 630:	learn: 0.0145402	total: 404ms	remaining: 236ms
# 631:	learn: 0.0145103	total: 404ms	remaining: 236ms
# 632:	learn: 0.0144623	total: 405ms	remaining: 235ms
# 633:	learn: 0.0144220	total: 406ms	remaining: 234ms
# 634:	learn: 0.0143998	total: 406ms	remaining: 233ms
# 635:	learn: 0.0143212	total: 407ms	remaining: 233ms
# 636:	learn: 0.0142524	total: 407ms	remaining: 232ms
# 637:	learn: 0.0141817	total: 408ms	remaining: 231ms
# 638:	learn: 0.0141372	total: 409ms	remaining: 231ms
# 639:	learn: 0.0140255	total: 409ms	remaining: 230ms
# 640:	learn: 0.0139839	total: 410ms	remaining: 230ms
# 641:	learn: 0.0139506	total: 411ms	remaining: 229ms
# 642:	learn: 0.0138840	total: 411ms	remaining: 228ms
# 643:	learn: 0.0138574	total: 412ms	remaining: 228ms
# 644:	learn: 0.0138144	total: 413ms	remaining: 227ms
# 645:	learn: 0.0137403	total: 413ms	remaining: 226ms
# 646:	learn: 0.0136969	total: 414ms	remaining: 226ms
# 647:	learn: 0.0136683	total: 414ms	remaining: 225ms
# 648:	learn: 0.0135941	total: 415ms	remaining: 224ms
# 649:	learn: 0.0135246	total: 416ms	remaining: 224ms
# 650:	learn: 0.0134579	total: 416ms	remaining: 223ms
# 651:	learn: 0.0133950	total: 417ms	remaining: 223ms
# 652:	learn: 0.0133289	total: 418ms	remaining: 222ms
# 653:	learn: 0.0132637	total: 418ms	remaining: 221ms
# 654:	learn: 0.0132338	total: 419ms	remaining: 221ms
# 655:	learn: 0.0131975	total: 419ms	remaining: 220ms
# 656:	learn: 0.0131341	total: 420ms	remaining: 219ms
# 657:	learn: 0.0131275	total: 421ms	remaining: 219ms
# 658:	learn: 0.0131190	total: 421ms	remaining: 218ms
# 659:	learn: 0.0131090	total: 422ms	remaining: 217ms
# 660:	learn: 0.0130797	total: 422ms	remaining: 217ms
# 661:	learn: 0.0130516	total: 423ms	remaining: 216ms
# 662:	learn: 0.0129904	total: 424ms	remaining: 215ms
# 663:	learn: 0.0129413	total: 424ms	remaining: 215ms
# 664:	learn: 0.0128660	total: 425ms	remaining: 214ms
# 665:	learn: 0.0128572	total: 425ms	remaining: 213ms
# 666:	learn: 0.0128193	total: 426ms	remaining: 213ms
# 667:	learn: 0.0127757	total: 427ms	remaining: 212ms
# 668:	learn: 0.0127424	total: 427ms	remaining: 211ms
# 669:	learn: 0.0127367	total: 428ms	remaining: 211ms
# 670:	learn: 0.0127281	total: 428ms	remaining: 210ms
# 671:	learn: 0.0127198	total: 429ms	remaining: 209ms
# 672:	learn: 0.0126882	total: 430ms	remaining: 209ms
# 673:	learn: 0.0126381	total: 431ms	remaining: 208ms
# 674:	learn: 0.0125736	total: 431ms	remaining: 208ms
# 675:	learn: 0.0125622	total: 432ms	remaining: 207ms
# 676:	learn: 0.0125390	total: 432ms	remaining: 206ms
# 677:	learn: 0.0125339	total: 433ms	remaining: 206ms
# 678:	learn: 0.0125198	total: 433ms	remaining: 205ms
# 679:	learn: 0.0124583	total: 434ms	remaining: 204ms
# 680:	learn: 0.0124414	total: 435ms	remaining: 204ms
# 681:	learn: 0.0124007	total: 435ms	remaining: 203ms
# 682:	learn: 0.0123395	total: 436ms	remaining: 202ms
# 683:	learn: 0.0122793	total: 436ms	remaining: 202ms
# 684:	learn: 0.0122412	total: 437ms	remaining: 201ms
# 685:	learn: 0.0121820	total: 438ms	remaining: 200ms
# 686:	learn: 0.0121092	total: 438ms	remaining: 200ms
# 687:	learn: 0.0121005	total: 439ms	remaining: 199ms
# 688:	learn: 0.0120419	total: 440ms	remaining: 198ms
# 689:	learn: 0.0119931	total: 440ms	remaining: 198ms
# 690:	learn: 0.0119809	total: 441ms	remaining: 197ms
# 691:	learn: 0.0119221	total: 441ms	remaining: 196ms
# 692:	learn: 0.0119065	total: 442ms	remaining: 196ms
# 693:	learn: 0.0118974	total: 442ms	remaining: 195ms
# 694:	learn: 0.0118498	total: 443ms	remaining: 194ms
# 695:	learn: 0.0117945	total: 444ms	remaining: 194ms
# 696:	learn: 0.0117354	total: 444ms	remaining: 193ms
# 697:	learn: 0.0116998	total: 445ms	remaining: 193ms
# 698:	learn: 0.0116568	total: 446ms	remaining: 192ms
# 699:	learn: 0.0116056	total: 446ms	remaining: 191ms
# 700:	learn: 0.0115703	total: 447ms	remaining: 191ms
# 701:	learn: 0.0115467	total: 448ms	remaining: 190ms
# 702:	learn: 0.0114947	total: 448ms	remaining: 189ms
# 703:	learn: 0.0114865	total: 449ms	remaining: 189ms
# 704:	learn: 0.0114608	total: 449ms	remaining: 188ms
# 705:	learn: 0.0114033	total: 450ms	remaining: 187ms
# 706:	learn: 0.0113661	total: 451ms	remaining: 187ms
# 707:	learn: 0.0112807	total: 451ms	remaining: 186ms
# 708:	learn: 0.0112154	total: 452ms	remaining: 185ms
# 709:	learn: 0.0111703	total: 452ms	remaining: 185ms
# 710:	learn: 0.0111259	total: 453ms	remaining: 184ms
# 711:	learn: 0.0110492	total: 453ms	remaining: 183ms
# 712:	learn: 0.0109823	total: 454ms	remaining: 183ms
# 713:	learn: 0.0109479	total: 455ms	remaining: 182ms
# 714:	learn: 0.0109136	total: 455ms	remaining: 181ms
# 715:	learn: 0.0109041	total: 456ms	remaining: 181ms
# 716:	learn: 0.0108696	total: 456ms	remaining: 180ms
# 717:	learn: 0.0108543	total: 457ms	remaining: 180ms
# 718:	learn: 0.0108289	total: 458ms	remaining: 179ms
# 719:	learn: 0.0107848	total: 458ms	remaining: 178ms
# 720:	learn: 0.0107733	total: 459ms	remaining: 178ms
# 721:	learn: 0.0107660	total: 459ms	remaining: 177ms
# 722:	learn: 0.0107574	total: 460ms	remaining: 176ms
# 723:	learn: 0.0107469	total: 461ms	remaining: 176ms
# 724:	learn: 0.0107242	total: 461ms	remaining: 175ms
# 725:	learn: 0.0106890	total: 462ms	remaining: 174ms
# 726:	learn: 0.0106418	total: 462ms	remaining: 174ms
# 727:	learn: 0.0105806	total: 463ms	remaining: 173ms
# 728:	learn: 0.0105760	total: 464ms	remaining: 172ms
# 729:	learn: 0.0105425	total: 464ms	remaining: 172ms
# 730:	learn: 0.0105263	total: 465ms	remaining: 171ms
# 731:	learn: 0.0104655	total: 465ms	remaining: 170ms
# 732:	learn: 0.0104515	total: 466ms	remaining: 170ms
# 733:	learn: 0.0104411	total: 467ms	remaining: 169ms
# 734:	learn: 0.0104024	total: 467ms	remaining: 168ms
# 735:	learn: 0.0103416	total: 468ms	remaining: 168ms
# 736:	learn: 0.0103094	total: 468ms	remaining: 167ms
# 737:	learn: 0.0102640	total: 469ms	remaining: 166ms
# 738:	learn: 0.0102109	total: 470ms	remaining: 166ms
# 739:	learn: 0.0101946	total: 470ms	remaining: 165ms
# 740:	learn: 0.0101318	total: 471ms	remaining: 165ms
# 741:	learn: 0.0100926	total: 471ms	remaining: 164ms
# 742:	learn: 0.0100543	total: 472ms	remaining: 163ms
# 743:	learn: 0.0100297	total: 473ms	remaining: 163ms
# 744:	learn: 0.0100101	total: 474ms	remaining: 162ms
# 745:	learn: 0.0099590	total: 474ms	remaining: 161ms
# 746:	learn: 0.0099099	total: 475ms	remaining: 161ms
# 747:	learn: 0.0098743	total: 475ms	remaining: 160ms
# 748:	learn: 0.0098491	total: 476ms	remaining: 159ms
# 749:	learn: 0.0097992	total: 476ms	remaining: 159ms
# 750:	learn: 0.0097662	total: 477ms	remaining: 158ms
# 751:	learn: 0.0097242	total: 478ms	remaining: 158ms
# 752:	learn: 0.0097047	total: 478ms	remaining: 157ms
# 753:	learn: 0.0096691	total: 479ms	remaining: 156ms
# 754:	learn: 0.0096302	total: 479ms	remaining: 156ms
# 755:	learn: 0.0096116	total: 480ms	remaining: 155ms
# 756:	learn: 0.0095613	total: 481ms	remaining: 154ms
# 757:	learn: 0.0095191	total: 481ms	remaining: 154ms
# 758:	learn: 0.0094816	total: 482ms	remaining: 153ms
# 759:	learn: 0.0094292	total: 482ms	remaining: 152ms
# 760:	learn: 0.0093848	total: 483ms	remaining: 152ms
# 761:	learn: 0.0093307	total: 484ms	remaining: 151ms
# 762:	learn: 0.0092962	total: 484ms	remaining: 150ms
# 763:	learn: 0.0092461	total: 485ms	remaining: 150ms
# 764:	learn: 0.0092028	total: 485ms	remaining: 149ms
# 765:	learn: 0.0091693	total: 486ms	remaining: 148ms
# 766:	learn: 0.0091570	total: 487ms	remaining: 148ms
# 767:	learn: 0.0091260	total: 487ms	remaining: 147ms
# 768:	learn: 0.0091036	total: 488ms	remaining: 147ms
# 769:	learn: 0.0090948	total: 488ms	remaining: 146ms
# 770:	learn: 0.0090872	total: 489ms	remaining: 145ms
# 771:	learn: 0.0090555	total: 489ms	remaining: 145ms
# 772:	learn: 0.0090483	total: 490ms	remaining: 144ms
# 773:	learn: 0.0089928	total: 491ms	remaining: 143ms
# 774:	learn: 0.0089586	total: 491ms	remaining: 143ms
# 775:	learn: 0.0089309	total: 492ms	remaining: 142ms
# 776:	learn: 0.0088940	total: 493ms	remaining: 141ms
# 777:	learn: 0.0088462	total: 493ms	remaining: 141ms
# 778:	learn: 0.0088075	total: 494ms	remaining: 140ms
# 779:	learn: 0.0087999	total: 495ms	remaining: 139ms
# 780:	learn: 0.0087433	total: 495ms	remaining: 139ms
# 781:	learn: 0.0087319	total: 496ms	remaining: 138ms
# 782:	learn: 0.0087034	total: 496ms	remaining: 138ms
# 783:	learn: 0.0086627	total: 497ms	remaining: 137ms
# 784:	learn: 0.0086001	total: 497ms	remaining: 136ms
# 785:	learn: 0.0085914	total: 498ms	remaining: 136ms
# 786:	learn: 0.0085764	total: 499ms	remaining: 135ms
# 787:	learn: 0.0085621	total: 499ms	remaining: 134ms
# 788:	learn: 0.0085404	total: 500ms	remaining: 134ms
# 789:	learn: 0.0085146	total: 501ms	remaining: 133ms
# 790:	learn: 0.0084837	total: 502ms	remaining: 133ms
# 791:	learn: 0.0084448	total: 502ms	remaining: 132ms
# 792:	learn: 0.0084167	total: 503ms	remaining: 131ms
# 793:	learn: 0.0083969	total: 503ms	remaining: 131ms
# 794:	learn: 0.0083739	total: 504ms	remaining: 130ms
# 795:	learn: 0.0083405	total: 505ms	remaining: 129ms
# 796:	learn: 0.0083308	total: 505ms	remaining: 129ms
# 797:	learn: 0.0083241	total: 506ms	remaining: 128ms
# 798:	learn: 0.0082945	total: 506ms	remaining: 127ms
# 799:	learn: 0.0082860	total: 507ms	remaining: 127ms
# 800:	learn: 0.0082751	total: 508ms	remaining: 126ms
# 801:	learn: 0.0082399	total: 508ms	remaining: 125ms
# 802:	learn: 0.0082099	total: 509ms	remaining: 125ms
# 803:	learn: 0.0081627	total: 509ms	remaining: 124ms
# 804:	learn: 0.0081551	total: 510ms	remaining: 124ms
# 805:	learn: 0.0081315	total: 511ms	remaining: 123ms
# 806:	learn: 0.0080979	total: 511ms	remaining: 122ms
# 807:	learn: 0.0080499	total: 512ms	remaining: 122ms
# 808:	learn: 0.0080186	total: 512ms	remaining: 121ms
# 809:	learn: 0.0079665	total: 513ms	remaining: 120ms
# 810:	learn: 0.0079252	total: 514ms	remaining: 120ms
# 811:	learn: 0.0079221	total: 515ms	remaining: 119ms
# 812:	learn: 0.0079121	total: 515ms	remaining: 118ms
# 813:	learn: 0.0078886	total: 516ms	remaining: 118ms
# 814:	learn: 0.0078476	total: 516ms	remaining: 117ms
# 815:	learn: 0.0078125	total: 517ms	remaining: 117ms
# 816:	learn: 0.0078050	total: 517ms	remaining: 116ms
# 817:	learn: 0.0077741	total: 518ms	remaining: 115ms
# 818:	learn: 0.0077407	total: 519ms	remaining: 115ms
# 819:	learn: 0.0077160	total: 520ms	remaining: 114ms
# 820:	learn: 0.0077098	total: 520ms	remaining: 113ms
# 821:	learn: 0.0076613	total: 521ms	remaining: 113ms
# 822:	learn: 0.0076451	total: 521ms	remaining: 112ms
# 823:	learn: 0.0076109	total: 522ms	remaining: 111ms
# 824:	learn: 0.0075772	total: 522ms	remaining: 111ms
# 825:	learn: 0.0075433	total: 523ms	remaining: 110ms
# 826:	learn: 0.0075046	total: 524ms	remaining: 110ms
# 827:	learn: 0.0074815	total: 524ms	remaining: 109ms
# 828:	learn: 0.0074508	total: 525ms	remaining: 108ms
# 829:	learn: 0.0074376	total: 525ms	remaining: 108ms
# 830:	learn: 0.0074176	total: 526ms	remaining: 107ms
# 831:	learn: 0.0073878	total: 527ms	remaining: 106ms
# 832:	learn: 0.0073708	total: 527ms	remaining: 106ms
# 833:	learn: 0.0073307	total: 528ms	remaining: 105ms
# 834:	learn: 0.0072931	total: 529ms	remaining: 104ms
# 835:	learn: 0.0072830	total: 529ms	remaining: 104ms
# 836:	learn: 0.0072625	total: 530ms	remaining: 103ms
# 837:	learn: 0.0072355	total: 531ms	remaining: 103ms
# 838:	learn: 0.0072250	total: 531ms	remaining: 102ms
# 839:	learn: 0.0071976	total: 532ms	remaining: 101ms
# 840:	learn: 0.0071599	total: 532ms	remaining: 101ms
# 841:	learn: 0.0071289	total: 533ms	remaining: 100ms
# 842:	learn: 0.0071066	total: 533ms	remaining: 99.4ms
# 843:	learn: 0.0070755	total: 534ms	remaining: 98.7ms
# 844:	learn: 0.0070429	total: 535ms	remaining: 98.1ms
# 845:	learn: 0.0070272	total: 535ms	remaining: 97.4ms
# 846:	learn: 0.0069964	total: 536ms	remaining: 96.8ms
# 847:	learn: 0.0069655	total: 537ms	remaining: 96.2ms
# 848:	learn: 0.0069619	total: 537ms	remaining: 95.5ms
# 849:	learn: 0.0069542	total: 538ms	remaining: 94.9ms
# 850:	learn: 0.0069190	total: 538ms	remaining: 94.3ms
# 851:	learn: 0.0068912	total: 539ms	remaining: 93.6ms
# 852:	learn: 0.0068830	total: 540ms	remaining: 93ms
# 853:	learn: 0.0068608	total: 540ms	remaining: 92.3ms
# 854:	learn: 0.0068310	total: 541ms	remaining: 91.7ms
# 855:	learn: 0.0068124	total: 541ms	remaining: 91.1ms
# 856:	learn: 0.0068001	total: 542ms	remaining: 90.5ms
# 857:	learn: 0.0067872	total: 543ms	remaining: 89.9ms
# 858:	learn: 0.0067441	total: 544ms	remaining: 89.3ms
# 859:	learn: 0.0067110	total: 545ms	remaining: 88.7ms
# 860:	learn: 0.0066942	total: 546ms	remaining: 88.1ms
# 861:	learn: 0.0066883	total: 546ms	remaining: 87.5ms
# 862:	learn: 0.0066577	total: 547ms	remaining: 86.9ms
# 863:	learn: 0.0066158	total: 548ms	remaining: 86.2ms
# 864:	learn: 0.0065799	total: 549ms	remaining: 85.6ms
# 865:	learn: 0.0065537	total: 549ms	remaining: 85ms
# 866:	learn: 0.0065333	total: 550ms	remaining: 84.3ms
# 867:	learn: 0.0065009	total: 551ms	remaining: 83.7ms
# 868:	learn: 0.0064715	total: 551ms	remaining: 83.1ms
# 869:	learn: 0.0064429	total: 552ms	remaining: 82.5ms
# 870:	learn: 0.0064204	total: 553ms	remaining: 81.8ms
# 871:	learn: 0.0063920	total: 553ms	remaining: 81.2ms
# 872:	learn: 0.0063564	total: 554ms	remaining: 80.6ms
# 873:	learn: 0.0063325	total: 555ms	remaining: 80ms
# 874:	learn: 0.0063117	total: 556ms	remaining: 79.4ms
# 875:	learn: 0.0062965	total: 556ms	remaining: 78.8ms
# 876:	learn: 0.0062738	total: 557ms	remaining: 78.1ms
# 877:	learn: 0.0062501	total: 558ms	remaining: 77.5ms
# 878:	learn: 0.0062388	total: 559ms	remaining: 76.9ms
# 879:	learn: 0.0061941	total: 559ms	remaining: 76.3ms
# 880:	learn: 0.0061615	total: 560ms	remaining: 75.7ms
# 881:	learn: 0.0061522	total: 561ms	remaining: 75ms
# 882:	learn: 0.0061282	total: 562ms	remaining: 74.4ms
# 883:	learn: 0.0060837	total: 562ms	remaining: 73.8ms
# 884:	learn: 0.0060569	total: 563ms	remaining: 73.2ms
# 885:	learn: 0.0060274	total: 564ms	remaining: 72.6ms
# 886:	learn: 0.0060066	total: 565ms	remaining: 71.9ms
# 887:	learn: 0.0059715	total: 565ms	remaining: 71.3ms
# 888:	learn: 0.0059520	total: 566ms	remaining: 70.7ms
# 889:	learn: 0.0059247	total: 566ms	remaining: 70ms
# 890:	learn: 0.0059043	total: 567ms	remaining: 69.4ms
# 891:	learn: 0.0058991	total: 568ms	remaining: 68.7ms
# 892:	learn: 0.0058912	total: 568ms	remaining: 68.1ms
# 893:	learn: 0.0058637	total: 569ms	remaining: 67.4ms
# 894:	learn: 0.0058369	total: 569ms	remaining: 66.8ms
# 895:	learn: 0.0058313	total: 570ms	remaining: 66.2ms
# 896:	learn: 0.0058267	total: 571ms	remaining: 65.5ms
# 897:	learn: 0.0058035	total: 571ms	remaining: 64.9ms
# 898:	learn: 0.0057980	total: 572ms	remaining: 64.2ms
# 899:	learn: 0.0057677	total: 572ms	remaining: 63.6ms
# 900:	learn: 0.0057465	total: 573ms	remaining: 63ms
# 901:	learn: 0.0057233	total: 574ms	remaining: 62.3ms
# 902:	learn: 0.0057027	total: 574ms	remaining: 61.7ms
# 903:	learn: 0.0056950	total: 575ms	remaining: 61ms
# 904:	learn: 0.0056620	total: 576ms	remaining: 60.4ms
# 905:	learn: 0.0056348	total: 576ms	remaining: 59.8ms
# 906:	learn: 0.0056158	total: 577ms	remaining: 59.1ms
# 907:	learn: 0.0055902	total: 577ms	remaining: 58.5ms
# 908:	learn: 0.0055854	total: 578ms	remaining: 57.8ms
# 909:	learn: 0.0055441	total: 578ms	remaining: 57.2ms
# 910:	learn: 0.0055244	total: 579ms	remaining: 56.6ms
# 911:	learn: 0.0054974	total: 580ms	remaining: 55.9ms
# 912:	learn: 0.0054909	total: 580ms	remaining: 55.3ms
# 913:	learn: 0.0054780	total: 581ms	remaining: 54.7ms
# 914:	learn: 0.0054692	total: 582ms	remaining: 54.1ms
# 915:	learn: 0.0054461	total: 582ms	remaining: 53.4ms
# 916:	learn: 0.0054331	total: 583ms	remaining: 52.8ms
# 917:	learn: 0.0054287	total: 584ms	remaining: 52.1ms
# 918:	learn: 0.0054122	total: 584ms	remaining: 51.5ms
# 919:	learn: 0.0054085	total: 585ms	remaining: 50.9ms
# 920:	learn: 0.0053930	total: 585ms	remaining: 50.2ms
# 921:	learn: 0.0053727	total: 586ms	remaining: 49.6ms
# 922:	learn: 0.0053690	total: 587ms	remaining: 48.9ms
# 923:	learn: 0.0053472	total: 587ms	remaining: 48.3ms
# 924:	learn: 0.0053211	total: 588ms	remaining: 47.7ms
# 925:	learn: 0.0052881	total: 588ms	remaining: 47ms
# 926:	learn: 0.0052846	total: 589ms	remaining: 46.4ms
# 927:	learn: 0.0052792	total: 590ms	remaining: 45.8ms
# 928:	learn: 0.0052531	total: 591ms	remaining: 45.1ms
# 929:	learn: 0.0052427	total: 591ms	remaining: 44.5ms
# 930:	learn: 0.0052063	total: 592ms	remaining: 43.9ms
# 931:	learn: 0.0052000	total: 592ms	remaining: 43.2ms
# 932:	learn: 0.0051968	total: 593ms	remaining: 42.6ms
# 933:	learn: 0.0051913	total: 593ms	remaining: 41.9ms
# 934:	learn: 0.0051880	total: 594ms	remaining: 41.3ms
# 935:	learn: 0.0051712	total: 595ms	remaining: 40.7ms
# 936:	learn: 0.0051460	total: 595ms	remaining: 40ms
# 937:	learn: 0.0051254	total: 596ms	remaining: 39.4ms
# 938:	learn: 0.0051145	total: 596ms	remaining: 38.7ms
# 939:	learn: 0.0050858	total: 597ms	remaining: 38.1ms
# 940:	learn: 0.0050801	total: 598ms	remaining: 37.5ms
# 941:	learn: 0.0050637	total: 599ms	remaining: 36.9ms
# 942:	learn: 0.0050483	total: 599ms	remaining: 36.2ms
# 943:	learn: 0.0050177	total: 600ms	remaining: 35.6ms
# 944:	learn: 0.0049929	total: 601ms	remaining: 35ms
# 945:	learn: 0.0049881	total: 601ms	remaining: 34.3ms
# 946:	learn: 0.0049634	total: 602ms	remaining: 33.7ms
# 947:	learn: 0.0049392	total: 602ms	remaining: 33ms
# 948:	learn: 0.0049238	total: 603ms	remaining: 32.4ms
# 949:	learn: 0.0048962	total: 603ms	remaining: 31.8ms
# 950:	learn: 0.0048759	total: 604ms	remaining: 31.1ms
# 951:	learn: 0.0048530	total: 605ms	remaining: 30.5ms
# 952:	learn: 0.0048345	total: 605ms	remaining: 29.9ms
# 953:	learn: 0.0048129	total: 606ms	remaining: 29.2ms
# 954:	learn: 0.0047880	total: 606ms	remaining: 28.6ms
# 955:	learn: 0.0047640	total: 607ms	remaining: 27.9ms
# 956:	learn: 0.0047529	total: 608ms	remaining: 27.3ms
# 957:	learn: 0.0047282	total: 608ms	remaining: 26.7ms
# 958:	learn: 0.0047108	total: 609ms	remaining: 26ms
# 959:	learn: 0.0046944	total: 610ms	remaining: 25.4ms
# 960:	learn: 0.0046688	total: 610ms	remaining: 24.8ms
# 961:	learn: 0.0046437	total: 611ms	remaining: 24.1ms
# 962:	learn: 0.0046403	total: 611ms	remaining: 23.5ms
# 963:	learn: 0.0046199	total: 612ms	remaining: 22.9ms
# 964:	learn: 0.0046025	total: 613ms	remaining: 22.2ms
# 965:	learn: 0.0045881	total: 613ms	remaining: 21.6ms
# 966:	learn: 0.0045736	total: 614ms	remaining: 21ms
# 967:	learn: 0.0045506	total: 615ms	remaining: 20.3ms
# 968:	learn: 0.0045325	total: 615ms	remaining: 19.7ms
# 969:	learn: 0.0045123	total: 616ms	remaining: 19ms
# 970:	learn: 0.0045091	total: 617ms	remaining: 18.4ms
# 971:	learn: 0.0045057	total: 617ms	remaining: 17.8ms
# 972:	learn: 0.0044816	total: 618ms	remaining: 17.1ms
# 973:	learn: 0.0044647	total: 618ms	remaining: 16.5ms
# 974:	learn: 0.0044594	total: 619ms	remaining: 15.9ms
# 975:	learn: 0.0044458	total: 620ms	remaining: 15.2ms
# 976:	learn: 0.0044282	total: 620ms	remaining: 14.6ms
# 977:	learn: 0.0044221	total: 621ms	remaining: 14ms
# 978:	learn: 0.0044093	total: 622ms	remaining: 13.3ms
# 979:	learn: 0.0043927	total: 622ms	remaining: 12.7ms
# 980:	learn: 0.0043777	total: 623ms	remaining: 12.1ms
# 981:	learn: 0.0043589	total: 624ms	remaining: 11.4ms
# 982:	learn: 0.0043416	total: 624ms	remaining: 10.8ms
# 983:	learn: 0.0043239	total: 625ms	remaining: 10.2ms
# 984:	learn: 0.0043008	total: 625ms	remaining: 9.53ms
# 985:	learn: 0.0042969	total: 626ms	remaining: 8.89ms
# 986:	learn: 0.0042793	total: 627ms	remaining: 8.25ms
# 987:	learn: 0.0042674	total: 627ms	remaining: 7.62ms
# 988:	learn: 0.0042538	total: 628ms	remaining: 6.98ms
# 989:	learn: 0.0042432	total: 628ms	remaining: 6.35ms
# 990:	learn: 0.0042294	total: 629ms	remaining: 5.71ms
# 991:	learn: 0.0042241	total: 630ms	remaining: 5.08ms
# 992:	learn: 0.0042075	total: 630ms	remaining: 4.44ms
# 993:	learn: 0.0041949	total: 631ms	remaining: 3.81ms
# 994:	learn: 0.0041774	total: 631ms	remaining: 3.17ms
# 995:	learn: 0.0041691	total: 632ms	remaining: 2.54ms
# 996:	learn: 0.0041662	total: 632ms	remaining: 1.9ms
# 997:	learn: 0.0041617	total: 633ms	remaining: 1.27ms
# 998:	learn: 0.0041576	total: 634ms	remaining: 634us
# 999:	learn: 0.0041406	total: 634ms	remaining: 0us

# %%
print(f"MAE on test data = {mean_absolute_error(y_test, wine_regressor.predict(x_test))}")
# Out:
# MAE on test data = 0.07733360438481368

# %% [markdown]
# ---
